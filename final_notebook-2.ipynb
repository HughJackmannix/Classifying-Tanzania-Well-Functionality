# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import seaborn as sns
import numpy as np
import statistics as stat

import cartopy.crs as ccrs
import cartopy.feature as cfeature

from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree
from sklearn import metrics
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report 
from sklearn.metrics import plot_confusion_matrix
from sklearn.ensemble import BaggingClassifier, RandomForestClassifier
from sklearn.svm import SVC

from imblearn.over_sampling import SMOTE

from xgboost import XGBClassifier

# %% [markdown]
# - Name: Jack Mannix
# - Cohort: Flatiron Data Science - April 2021
# - Instructor : Abhineet Kulkarn

# %% [markdown]
# # Business Problem

# %% [markdown]
# WaterTanzania, a nonprofit, wants to improve access to water across Tanzania. To do so, they want to be able to send alerts to the entities in charge of a well(s) to check the status its functional status. Ontop of sending alerts when a well is deemed 'non-functional,' WaterTanzania also wants to send precautionary alerts based on observed well characteristics in order to repair wells before they become 'Non-functional'. With this goal in mind, the nonprofit needs an algorithm that can accurately predict the status of a well, and  prioritize minimal false predictions for wells that are actually 'non-functioning.'

# %% [markdown]
# # Import

# %%
sns.set_style('darkgrid')

# %%
df_values = pd.read_csv('data/values.csv')
df_labels = pd.read_csv('data/labels.csv')

df = pd.merge(df_values, df_labels, on='id')

# %% [markdown]
# # Business Problem

# %% [markdown]
# WaterTanzania, a nonprofit, wants to improve access to water across Tanzania. To do so, they want to be able to send alerts to the entities in charge of a well(s) to check the status its functional status. Ontop of sending alerts when a well is deemed 'non-functional,' WaterTanzania also wants to send precautionary alerts based on observed well characteristics in order to repair wells before they become 'Non-functional'. With this goal in mind, the nonprofit needs an algorithm that can accurately predict the status of a well, and  prioritize minimal false predictions for wells that are actually 'non-functioning.'

# %% [markdown]
# # Scrubbing

# %%
df.drop('id', axis=1, inplace=True)

# %%
df.isna().sum()
# Out:
# amount_tsh                   0
# date_recorded                0
# funder                    3635
# gps_height                   0
# installer                 3655
# longitude                    0
# latitude                     0
# wpt_name                     0
# num_private                  0
# basin                        0
# subvillage                 371
# region                       0
# region_code                  0
# district_code                0
# lga                          0
# ward                         0
# population                   0
# public_meeting            3334
# recorded_by                  0
# scheme_management         3877
# scheme_name              28166
# permit                    3056
# construction_year            0
# extraction_type              0
# extraction_type_group        0
# extraction_type_class        0
# management                   0
# management_group             0
# payment                      0
# payment_type                 0
# water_quality                0
# quality_group                0
# quantity                     0
# quantity_group               0
# source                       0
# source_type                  0
# source_class                 0
# waterpoint_type              0
# waterpoint_type_group        0
# status_group                 0
# dtype: int64

# %%
df.status_group.value_counts()
# Out:
# functional                 32259
# non functional             22824
# functional needs repair     4317
# Name: status_group, dtype: int64

# %% [markdown]
# #### Null Values

# %% [markdown]
# Dropping null values results in the loss of approx 10,000 entries

# %% [markdown]
# I will one-hot-encode 'null columns' for the features that contain these null values during preproccessing (Modeling Phase)

# %% [markdown]
# #### Dropping Columns

# %%
df.drop('scheme_name', axis=1, inplace=True)

# %%
df.drop('subvillage', axis=1, inplace=True)

# %%
df.drop('waterpoint_type_group', axis=1, inplace=True)

# %%
df.drop('quantity_group', axis=1, inplace=True)

# %%
df.drop('water_quality', axis=1, inplace=True)

# %%
df.drop('payment', axis=1, inplace=True)

# %% [markdown]
# 1. **Dropped Columns:**
#     - scheme_name (over half of values are null)
#     - subvillage (too many unique string values. Better geographical data exists)
#     - waterpoint_type_group (redundant)
#     - quantity_group (redundant)
#     - payment (redundant)
#     - water_quality (redundant)

# %% [markdown]
# #### Grouping Low-Frequency Values

# %%
df = df.replace({'funder': 'Ministry Of Water'}, 'Government Of Tanzania')

series = pd.value_counts(df['funder'])
mask = (series/series.sum() * 100).lt(1.75)
df['funder'] = np.where(df['funder'].isin(series[mask].index),'Other',df['funder'])

df = df.replace({'funder': '0'}, 'Other')

# %%
df['funder'].value_counts()
# Out:
# Other                     34462
# Government Of Tanzania     9674
# Danida                     3114
# Hesawa                     2202
# Rwssp                      1374
# World Bank                 1349
# Kkkt                       1287
# World Vision               1246
# Unicef                     1057
# Name: funder, dtype: int64

# %%
plt.figure(figsize=(10,10))
sns.countplot(y='funder', hue='status_group', data=df)
# Out:
# <AxesSubplot:xlabel='count', ylabel='funder'>

# %%
# groupby_test = df.groupby('funder').agg('count').reset_index()
# groupby_test.head()
# sns.barplot(x='status_group', y='funder', data=groupby_test[groupby_test['status_group'] > 1000])

# %% [markdown]
# I have strong reason to believe that 'Government of Tanzania' and 'Ministry of Water' can be lumped into one: https://en.wikipedia.org/wiki/Ministry_of_Water_and_Irrigation

# %%
#aggregating
df = df.replace({'installer': 'hesawa'}, 'HESAWA')
df = df.replace({'installer': 'Central government'}, 'Government')
df = df.replace({'installer': 'Commu'}, 'Community')

#cleaning 
df = df.replace({'installer': 'DANID'}, 'DANIDA' )

# %%
series = pd.value_counts(df['installer'])
mask = (series/series.sum() * 100).lt(1.75)
df['installer'] = np.where(df['installer'].isin(series[mask].index),'Other',df['installer'])
df['installer'].value_counts()

df = df.replace({'installer': '0'}, 'Other')

# %%
df['installer'].value_counts()
# Out:
# Other         31475
# DWE           17402
# Government     2447
# Community      1613
# DANIDA         1602
# RWE            1206
# Name: installer, dtype: int64

# %%
plt.figure(figsize=(10,10))
sns.countplot(y='installer', hue='status_group', data=df)
# Out:
# <AxesSubplot:xlabel='count', ylabel='installer'>

# %% [markdown]
# The following values have been aggregated due to the belief that they were entered with spelling errors

# %%
#aggregating
df = df.replace({'wpt_name': 'Shuleni'}, 'School')
df = df.replace({'wpt_name': 'Shule'}, 'School')
df = df.replace({'wpt_name': 'Shule Ya Misingi'}, 'School')

series = pd.value_counts(df['wpt_name'])
mask = (series/series.sum() * 100).lt(1.55)
df['wpt_name'] = np.where(df['wpt_name'].isin(series[mask].index),'Other',df['wpt_name'])

df = df.replace({'wpt_name': 'none'}, 'Other')

# %%
df['wpt_name'].value_counts()
# Out:
# Other     57292
# School     2108
# Name: wpt_name, dtype: int64

# %%
plt.figure(figsize=(10,10))
sns.countplot(y='wpt_name', hue='status_group', data=df)
# Out:
# <AxesSubplot:xlabel='count', ylabel='wpt_name'>

# %% [markdown]
# #### construction_year (missing values)

# %%
sorted(df['construction_year'].unique())
# Out:
# [0,
#  1960,
#  1961,
#  1962,
#  1963,
#  1964,
#  1965,
#  1966,
#  1967,
#  1968,
#  1969,
#  1970,
#  1971,
#  1972,
#  1973,
#  1974,
#  1975,
#  1976,
#  1977,
#  1978,
#  1979,
#  1980,
#  1981,
#  1982,
#  1983,
#  1984,
#  1985,
#  1986,
#  1987,
#  1988,
#  1989,
#  1990,
#  1991,
#  1992,
#  1993,
#  1994,
#  1995,
#  1996,
#  1997,
#  1998,
#  1999,
#  2000,
#  2001,
#  2002,
#  2003,
#  2004,
#  2005,
#  2006,
#  2007,
#  2008,
#  2009,
#  2010,
#  2011,
#  2012,
#  2013]

# %% [markdown]
# #### well_age

# %% [markdown]
# Before I bin the construction_year feature, I am going to make use of what information is given to calculate the age of each well

# %%
df['well_age'] = 2013 - df['construction_year']
df = df.replace({'well_age': 2013}, 100 )

# %% [markdown]
# #### binning construction_year - NOT PERFORMED

# %%
df[(df['construction_year'] < 1970)]['construction_year'].value_counts().sum() - 20709
# Out:
# 538

# %%
df[(df['construction_year'] < 1980) & (df['construction_year'] > 1969)]['construction_year'].value_counts().sum()
# Out:
# 4406

# %%
df[(df['construction_year'] < 1990) & (df['construction_year'] > 1979)]['construction_year'].value_counts().sum()
# Out:
# 5578

# %%
df[(df['construction_year'] < 2000) & (df['construction_year'] > 1989)]['construction_year'].value_counts().sum()
# Out:
# 7678

# %%
df[(df['construction_year'] < 2010) & (df['construction_year'] > 2000)]['construction_year'].value_counts().sum()
# Out:
# 13239

# %%
df[(df['construction_year'] >= 2010)]['construction_year'].value_counts().sum()
# Out:
# 5161

# %% [markdown]
# **OBSERVATION**
# 1. Nearly half of the entries are missing a construction year
# 2. Construction year goes back consistantly to 1960
#     - I will bin construction years and create a 'null' column during preprocessing
#     - BINS = 1960 - 1989, 1990-199, 2000-2009, 2010+

# %%
# bins=[-1,1959,1989,1999,2009,2014]

# df['year_constructed']= pd.cut(df['construction_year'],
#                               bins=bins,
#                               labels= ['Unknown','60s - 80s', '1990s', '2000s', '2010+'])

# df.drop('construction_year', axis=1, inplace=True)

# %% [markdown]
# #### Assessing Geographic Data

# %% [markdown]
# - subvillage
# - region
# - region_code
# - district_code
# - lga
# - ward

# %%
df['region'].value_counts()
# Out:
# Iringa           5294
# Shinyanga        4982
# Mbeya            4639
# Kilimanjaro      4379
# Morogoro         4006
# Arusha           3350
# Kagera           3316
# Mwanza           3102
# Kigoma           2816
# Ruvuma           2640
# Pwani            2635
# Tanga            2547
# Dodoma           2201
# Singida          2093
# Mara             1969
# Tabora           1959
# Rukwa            1808
# Mtwara           1730
# Manyara          1583
# Lindi            1546
# Dar es Salaam     805
# Name: region, dtype: int64

# %%
df['region_code'].value_counts()
# Out:
# 11    5300
# 17    5011
# 12    4639
# 3     4379
# 5     4040
# 18    3324
# 19    3047
# 2     3024
# 16    2816
# 10    2640
# 4     2513
# 1     2201
# 13    2093
# 14    1979
# 20    1969
# 15    1808
# 6     1609
# 21    1583
# 80    1238
# 60    1025
# 90     917
# 7      805
# 99     423
# 9      390
# 24     326
# 8      300
# 40       1
# Name: region_code, dtype: int64

# %%
len(df['region'].unique()) - len(df['region_code'].unique())
# Out:
# -6

# %%
df['district_code'].value_counts()
# Out:
# 1     12203
# 2     11173
# 3      9998
# 4      8999
# 5      4356
# 6      4074
# 7      3343
# 8      1043
# 30      995
# 33      874
# 53      745
# 43      505
# 13      391
# 23      293
# 63      195
# 62      109
# 60       63
# 0        23
# 80       12
# 67        6
# Name: district_code, dtype: int64

# %%
len(df['district_code'].unique()) - len(df['region'].unique())
# Out:
# -1

# %%
df['lga'].value_counts()
# Out:
# Njombe          2503
# Arusha Rural    1252
# Moshi Rural     1251
# Bariadi         1177
# Rungwe          1106
#                 ...
# Moshi Urban       79
# Kigoma Urban      71
# Arusha Urban      63
# Lindi Urban       21
# Nyamagana          1
# Name: lga, Length: 125, dtype: int64

# %%
df['ward'].value_counts()
# Out:
# Igosi          307
# Imalinyi       252
# Siha Kati      232
# Mdandu         231
# Nduruma        217
#               ...
# Mlimani          1
# Machinjioni      1
# Nyamtinga        1
# Uchindile        1
# Kinungu          1
# Name: ward, Length: 2092, dtype: int64

# %% [markdown]
# Based upon value counts, it would appear that 'region' will be the cleanest geographical data to work with

# %% [markdown]
# #### Continuous Data

# %%
df.describe()
# Out:
#           amount_tsh    gps_height     longitude      latitude   num_private  \
# count   59400.000000  59400.000000  59400.000000  5.940000e+04  59400.000000
# mean      317.650385    668.297239     34.077427 -5.706033e+00      0.474141
# std      2997.574558    693.116350      6.567432  2.946019e+00     12.236230
# min         0.000000    -90.000000      0.000000 -1.164944e+01      0.000000
# 25%         0.000000      0.000000     33.090347 -8.540621e+00      0.000000
# 50%         0.000000    369.000000     34.908743 -5.021597e+00      0.000000
# 75%        20.000000   1319.250000     37.178387 -3.326156e+00      0.000000
# max    350000.000000   2770.000000     40.345193 -2.000000e-08   1776.000000
#
#         region_code  district_code    population  construction_year  \
# count  59400.000000   59400.000000  59400.000000       59400.000000
# mean      15.297003       5.629747    179.909983        1300.652475
# std       17.587406       9.633649    471.482176         951.620547
# min        1.000000       0.000000      0.000000           0.000000
# 25%        5.000000       2.000000      0.000000           0.000000
# 50%       12.000000       3.000000     25.000000        1986.000000
# 75%       17.000000       5.000000    215.000000        2004.000000
# max       99.000000      80.000000  30500.000000        2013.000000
#
#            well_age
# count  59400.000000
# mean      45.406162
# std       41.190108
# min        0.000000
# 25%        9.000000
# 50%       27.000000
# 75%      100.000000
# max      100.000000

# %% [markdown]
# #### Dealing with Population

# %%
df[(df['population'] == 0)]
# Out:
#        amount_tsh date_recorded                  funder  gps_height  \
# 4             0.0    2011-07-13                   Other           0
# 6             0.0    2012-10-01                   Other           0
# 7             0.0    2012-10-09                   Rwssp           0
# 8             0.0    2012-11-03                   Other           0
# 9             0.0    2011-08-03                   Other           0
# ...           ...           ...                     ...         ...
# 59384         0.0    2011-07-10                   Other           0
# 59392         0.0    2011-04-15  Government Of Tanzania           0
# 59393         0.0    2012-10-27                   Other           0
# 59397         0.0    2011-04-11                     NaN           0
# 59398         0.0    2011-03-08                   Other           0
#
#         installer  longitude  latitude wpt_name  num_private            basin  \
# 4           Other  31.130847 -1.825359   School            0    Lake Victoria
# 6           Other  33.362410 -3.766365    Other            0         Internal
# 7             DWE  32.620617 -4.226198    Other            0  Lake Tanganyika
# 8           Other  32.711100 -5.146712    Other            0  Lake Tanganyika
# 9           Other  30.626991 -1.257051    Other            0    Lake Victoria
# ...           ...        ...       ...      ...          ...              ...
# 59384       Other  30.667805 -2.483710    Other            0    Lake Victoria
# 59392  Government  33.009440 -8.520888    Other            0       Lake Rukwa
# 59393       Other  33.866852 -4.287410    Other            0         Internal
# 59397         NaN  34.017087 -8.750434    Other            0           Rufiji
# 59398       Other  35.861315 -6.378573    Other            0           Rufiji
#
#        ... management_group  payment_type  quality_group      quantity  \
# 4      ...            other     never pay           good      seasonal
# 6      ...       user-group     never pay           good        enough
# 7      ...       user-group       unknown          milky        enough
# 8      ...       user-group     never pay          salty      seasonal
# 9      ...       user-group     never pay           good        enough
# ...    ...              ...           ...            ...           ...
# 59384  ...       user-group     never pay           good  insufficient
# 59392  ...       user-group     never pay           good        enough
# 59393  ...       commercial    per bucket           good  insufficient
# 59397  ...       user-group       monthly       fluoride        enough
# 59398  ...       user-group     never pay           good  insufficient
#
#                      source           source_type source_class  \
# 4      rainwater harvesting  rainwater harvesting      surface
# 6               machine dbh              borehole  groundwater
# 7              shallow well          shallow well  groundwater
# 8               machine dbh              borehole  groundwater
# 9              shallow well          shallow well  groundwater
# ...                     ...                   ...          ...
# 59384                spring                spring  groundwater
# 59392                spring                spring  groundwater
# 59393                   dam                   dam      surface
# 59397           machine dbh              borehole  groundwater
# 59398          shallow well          shallow well  groundwater
#
#           waterpoint_type    status_group well_age
# 4      communal standpipe      functional      100
# 6               hand pump  non functional      100
# 7               hand pump  non functional      100
# 8               hand pump  non functional      100
# 9               hand pump      functional      100
# ...                   ...             ...      ...
# 59384  communal standpipe  non functional      100
# 59392  communal standpipe  non functional      100
# 59393               other      functional      100
# 59397           hand pump      functional      100
# 59398           hand pump      functional      100
#
# [21381 rows x 35 columns]

# %%
df['population'].value_counts()
# Out:
# 0       21381
# 1        7025
# 200      1940
# 150      1892
# 250      1681
#         ...
# 3241        1
# 1960        1
# 1685        1
# 2248        1
# 1439        1
# Name: population, Length: 1049, dtype: int64

# %% [markdown]
# Nearly half the data for 'population' is 0 and 1

# %% [markdown]
# #### gps_height (Altitude)

# %%
df['altitude'] = df['gps_height']
df.drop('gps_height', axis=1, inplace=True)

# %%
sns.histplot(df['altitude'])
# Out:
# <AxesSubplot:xlabel='altitude', ylabel='Count'>

# %% [markdown]
# **OBSERVATION**
# 1. While 0 is an acceptable value for altitude, I do not believe that there are this many wells at an altitude of 0

# %% [markdown]
# #### Month Recorded

# %% [markdown]
# Tanzania experiences its wetest season in March/April, and its driest during June/July/August

# %% [markdown]
# The month the status of the well was recorded could be revealing

# %%
df['month_recorded']=pd.to_datetime(df['date_recorded']).dt.month
df['year_recorded']=pd.to_datetime(df['date_recorded']).dt.year

# %%
df.drop('date_recorded', axis=1, inplace=True)

# %%
df = df[(df['year_recorded']) > 2005]

# %% [markdown]
# ## Revisiting Null Values

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 59369 entries, 0 to 59399
# Data columns (total 36 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   amount_tsh             59369 non-null  float64
#  1   funder                 55736 non-null  object
#  2   installer              55716 non-null  object
#  3   longitude              59369 non-null  float64
#  4   latitude               59369 non-null  float64
#  5   wpt_name               59369 non-null  object
#  6   num_private            59369 non-null  int64
#  7   basin                  59369 non-null  object
#  8   region                 59369 non-null  object
#  9   region_code            59369 non-null  int64
#  10  district_code          59369 non-null  int64
#  11  lga                    59369 non-null  object
#  12  ward                   59369 non-null  object
#  13  population             59369 non-null  int64
#  14  public_meeting         56041 non-null  object
#  15  recorded_by            59369 non-null  object
#  16  scheme_management      55496 non-null  object
#  17  permit                 56314 non-null  object
#  18  construction_year      59369 non-null  int64
#  19  extraction_type        59369 non-null  object
#  20  extraction_type_group  59369 non-null  object
#  21  extraction_type_class  59369 non-null  object
#  22  management             59369 non-null  object
#  23  management_group       59369 non-null  object
#  24  payment_type           59369 non-null  object
#  25  quality_group          59369 non-null  object
#  26  quantity               59369 non-null  object
#  27  source                 59369 non-null  object
#  28  source_type            59369 non-null  object
#  29  source_class           59369 non-null  object
#  30  waterpoint_type        59369 non-null  object
#  31  status_group           59369 non-null  object
#  32  well_age               59369 non-null  int64
#  33  altitude               59369 non-null  int64
#  34  month_recorded         59369 non-null  int64
#  35  year_recorded          59369 non-null  int64
# dtypes: float64(3), int64(9), object(24)
# memory usage: 16.8+ MB

# %%
df.dropna(inplace=True)

# %% [markdown]
# Dropping Null values will still leave dataset with just under 50,000 entries

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 48630 entries, 0 to 59399
# Data columns (total 36 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   amount_tsh             48630 non-null  float64
#  1   funder                 48630 non-null  object
#  2   installer              48630 non-null  object
#  3   longitude              48630 non-null  float64
#  4   latitude               48630 non-null  float64
#  5   wpt_name               48630 non-null  object
#  6   num_private            48630 non-null  int64
#  7   basin                  48630 non-null  object
#  8   region                 48630 non-null  object
#  9   region_code            48630 non-null  int64
#  10  district_code          48630 non-null  int64
#  11  lga                    48630 non-null  object
#  12  ward                   48630 non-null  object
#  13  population             48630 non-null  int64
#  14  public_meeting         48630 non-null  object
#  15  recorded_by            48630 non-null  object
#  16  scheme_management      48630 non-null  object
#  17  permit                 48630 non-null  object
#  18  construction_year      48630 non-null  int64
#  19  extraction_type        48630 non-null  object
#  20  extraction_type_group  48630 non-null  object
#  21  extraction_type_class  48630 non-null  object
#  22  management             48630 non-null  object
#  23  management_group       48630 non-null  object
#  24  payment_type           48630 non-null  object
#  25  quality_group          48630 non-null  object
#  26  quantity               48630 non-null  object
#  27  source                 48630 non-null  object
#  28  source_type            48630 non-null  object
#  29  source_class           48630 non-null  object
#  30  waterpoint_type        48630 non-null  object
#  31  status_group           48630 non-null  object
#  32  well_age               48630 non-null  int64
#  33  altitude               48630 non-null  int64
#  34  month_recorded         48630 non-null  int64
#  35  year_recorded          48630 non-null  int64
# dtypes: float64(3), int64(9), object(24)
# memory usage: 13.7+ MB

# %% [markdown]
# # Dropping Categorical Features

# %% [markdown]
# - As it stands, my data will have over 1,000 features if the categorical features are left as is
# - There are many features that are somewhat repetitive, I will be dropping which I belive the most redundant / unnecessary

# %%
df['source_type'].value_counts()
# Out:
# spring                  14979
# shallow well            12409
# borehole                 9733
# river/lake               9109
# rainwater harvesting     1605
# dam                       581
# other                     214
# Name: source_type, dtype: int64

# %%
df['source_class'].value_counts()
# Out:
# groundwater    37121
# surface        11295
# unknown          214
# Name: source_class, dtype: int64

# %%
df['source'].value_counts()
# Out:
# spring                  14979
# shallow well            12409
# machine dbh              8955
# river                    8504
# rainwater harvesting     1605
# hand dtw                  778
# lake                      605
# dam                       581
# other                     182
# unknown                    32
# Name: source, dtype: int64

# %%
df.drop('source_type', axis=1, inplace=True)

# %%
df['payment_type'].value_counts()
# Out:
# never pay     20771
# per bucket     8112
# monthly        7542
# unknown        4169
# on failure     3640
# annually       3468
# other           928
# Name: payment_type, dtype: int64

# %%
df['management_group'].value_counts()
# Out:
# user-group    43633
# commercial     3045
# parastatal     1330
# other           548
# unknown          74
# Name: management_group, dtype: int64

# %%
df['extraction_type'].value_counts()
# Out:
# gravity                      23159
# nira/tanira                   6259
# other                         4537
# submersible                   3753
# swn 80                        2857
# mono                          2499
# india mark ii                 2045
# afridev                       1346
# ksb                           1330
# other - rope pump              212
# other - swn 81                 199
# windmill                       104
# cemo                            89
# india mark iii                  86
# other - play pump               76
# walimi                          46
# climax                          32
# other - mkulima/shinyanga        1
# Name: extraction_type, dtype: int64

# %%
df['extraction_type_group'].value_counts()
# Out:
# gravity            23159
# nira/tanira         6259
# submersible         5083
# other               4537
# swn 80              2857
# mono                2499
# india mark ii       2045
# afridev             1346
# other handpump       322
# rope pump            212
# other motorpump      121
# wind-powered         104
# india mark iii        86
# Name: extraction_type_group, dtype: int64

# %%
df.drop('extraction_type', axis=1, inplace=True)

# %%
df['extraction_type_class'].value_counts()
# Out:
# gravity         23159
# handpump        12915
# submersible      5083
# other            4537
# motorpump        2620
# rope pump         212
# wind-powered      104
# Name: extraction_type_class, dtype: int64

# %%
df['scheme_management'].value_counts()
# Out:
# VWC                 32681
# WUG                  4237
# Water authority      2919
# WUA                  2634
# Water Board          2489
# Parastatal           1293
# Company              1028
# Private operator      804
# Other                 376
# SWC                    97
# Trust                  71
# None                    1
# Name: scheme_management, dtype: int64

# %%
df['recorded_by'].value_counts()
# Out:
# GeoData Consultants Ltd    48630
# Name: recorded_by, dtype: int64

# %%
df.drop('recorded_by', axis=1, inplace=True)

# %%
len(df['ward'].unique())
# Out:
# 1875

# %%
df.drop('ward', axis=1, inplace=True)

# %%
df['lga'].value_counts()
# Out:
# Njombe           2454
# Moshi Rural      1226
# Arusha Rural     1173
# Kilosa           1057
# Kasulu           1039
#                  ...
# Tarime             39
# Ilala              36
# Ileje              27
# Singida Rural      17
# Nyamagana           1
# Name: lga, Length: 118, dtype: int64

# %%
df.drop('lga', axis=1, inplace=True)

# %% [markdown]
# **FEATURES DROPPED**
# 1. source_type
# 2. extraction_type
# 3. recorded_by
# 4. ward
# 5. lga

# %% [markdown]
# # EDA

# %%
df.describe()
# Out:
#           amount_tsh     longitude      latitude   num_private   region_code  \
# count   48630.000000  48630.000000  4.863000e+04  48630.000000  48630.000000
# mean      357.870952     34.230648 -5.703317e+00      0.548262     14.684598
# std      2818.635008      6.309842  2.860211e+00     13.244462     17.199136
# min         0.000000      0.000000 -1.164944e+01      0.000000      1.000000
# 25%         0.000000     33.050844 -8.219467e+00      0.000000      5.000000
# 50%         0.000000     35.265112 -5.017793e+00      0.000000     12.000000
# 75%        50.000000     37.338478 -3.337886e+00      0.000000     17.000000
# max    250000.000000     40.323402 -2.000000e-08   1776.000000     99.000000
#
#        district_code    population  construction_year      well_age  \
# count   48630.000000  48630.000000       48630.000000  48630.000000
# mean        5.730393    175.389595        1332.920193     44.104668
# std         9.665276    471.061012         940.708415     40.767786
# min         0.000000      0.000000           0.000000      0.000000
# 25%         2.000000      0.000000           0.000000      8.000000
# 50%         3.000000     30.000000        1986.000000     27.000000
# 75%         5.000000    200.000000        2005.000000    100.000000
# max        80.000000  30500.000000        2013.000000    100.000000
#
#            altitude  month_recorded  year_recorded
# count  48630.000000    48630.000000   48630.000000
# mean     696.445157        4.318857    2011.899712
# std      698.813656        2.992206       0.944249
# min      -90.000000        1.000000    2011.000000
# 25%        0.000000        2.000000    2011.000000
# 50%      452.000000        3.000000    2011.000000
# 75%     1332.000000        7.000000    2013.000000
# max     2770.000000       12.000000    2013.000000

# %%
fig, ax = plt.subplots(figsize=(10,5))


imbalance_plot= sns.countplot(ax=ax,
              x='status_group', 
              data=df,
             color = 'orange')

plt.xticks([0,1,2], 
           ['Functional', 'Non-Functional', 'Functional-Needs Repair'],
          fontsize=12)
plt.yticks(fontsize=12)
plt.xlabel(xlabel='Status', fontsize=14)
plt.ylabel(ylabel='Count', fontsize=14)
plt.title('Class Imbalance', fontsize=15)
plt.savefig('images/class_imbalance');

# %% [markdown]
# **OBSERVATION**
# 1. There are far more functional wells than non-functional / needs repair
# 2. I will need to address the class imbalances during preprocessing / modeling

# %% [markdown]
# #### Feature - amount_tsh

# %%
sns.scatterplot(x='status_group', y='amount_tsh', data=df)
# Out:
# <AxesSubplot:xlabel='status_group', ylabel='amount_tsh'>

# %%
tsh_df = df

# %%
tsh_df = tsh_df[(tsh_df['amount_tsh'] < 150000)]

# %%
sns.scatterplot(x='status_group', y='amount_tsh', data=tsh_df)
# Out:
# <AxesSubplot:xlabel='status_group', ylabel='amount_tsh'>

# %% [markdown]
# **OBSERVATION**
# 1. It would appear that higher amounts of static head correlates with being functional; however it is very likely that this is due to the class imbalance

# %% [markdown]
# #### Feature - Funder - DROPPED

# %%
plt.figure(figsize=(10,10))
sns.countplot(y='funder', hue='status_group', data=df)
# Out:
# <AxesSubplot:xlabel='count', ylabel='funder'>

# %%
df.drop('funder', axis=1, inplace=True)

# %% [markdown]
# #### Feature - installer - DROPPED

# %%
plt.figure(figsize=(10,10))
sns.countplot(y='installer', hue='status_group', data=df)
# Out:
# <AxesSubplot:xlabel='count', ylabel='installer'>

# %%
df.drop('installer', axis=1, inplace=True)

# %% [markdown]
# #### Feature - management_group

# %%
plt.figure(figsize=(10,10))
sns.countplot(y='management_group', hue='status_group', data=df)
# Out:
# <AxesSubplot:xlabel='count', ylabel='management_group'>

# %% [markdown]
# #### Feature - management - DROPPED

# %%
plt.figure(figsize=(10,10))
sns.countplot(y='management', hue='status_group', data=df)
# Out:
# <AxesSubplot:xlabel='count', ylabel='management'>

# %%
df.drop('management',axis=1, inplace=True)

# %% [markdown]
# #### Feature - population

# %%
sns.scatterplot(x='status_group', y='population', data=df)
# Out:
# <AxesSubplot:xlabel='status_group', ylabel='population'>

# %%
df.groupby('status_group').population.median()
# Out:
# status_group
# functional                 40
# functional needs repair    50
# non functional              1
# Name: population, dtype: int64

# %% [markdown]
# **OBSERVATION**
# 1. small populations may correlate with non-functional wells, as it may be more imperative that resources are spent on more populous wells
# 2. functional wells may have a slightly smaller associated population due to less frequent use

# %%
df[(df['population'] > 20000)]['region']
# Out:
# 30537    Tanga
# Name: region, dtype: object

# %% [markdown]
# Tanga is a large port city in the NorthEast of Tanzania, this datapoint could make sense
# https://en.wikipedia.org/wiki/Tanga,_Tanzania

# %% [markdown]
# #### Feature - altitude

# %%
sns.scatterplot(x='status_group', y='altitude', data=df)
# Out:
# <AxesSubplot:xlabel='status_group', ylabel='altitude'>

# %% [markdown]
# #### Feature - well_age

# %%
age_df = df[(df['well_age'] < 100)]

# %%
sns.scatterplot(x='status_group', y='well_age', data=age_df)
# Out:
# <AxesSubplot:xlabel='status_group', ylabel='well_age'>

# %%
plt.figure(figsize=(10,10))
sns.countplot(y='well_age', hue='status_group', data=age_df)
# Out:
# <AxesSubplot:xlabel='count', ylabel='well_age'>

# %% [markdown]
# **OBSERVATION**
# 1. there are typically more non-functional wells than functional wells for wells 28 years and over

# %% [markdown]
# #### Feature - Month Recorded

# %%
plt.figure(figsize=(10,10))
sns.countplot(y='month_recorded', hue='status_group', data=df)
# Out:
# <AxesSubplot:xlabel='count', ylabel='month_recorded'>

# %% [markdown]
# **OBSERVATION**
# 1. most of the data collected is collected in the first quarter of the year (Jan - March)
# 2. May, July, September, and December seem to have very little recordings
# 3. June - October are the driest seasons: it would appear that there is a spike in recordings halfway through the dry season

# %% [markdown]
# #### Feature - Year Recorded - DROPPED

# %%
plt.figure(figsize=(10,10))
sns.countplot(y='year_recorded', hue='status_group', data=df)
# Out:
# <AxesSubplot:xlabel='count', ylabel='year_recorded'>

# %%
df.drop('year_recorded', axis=1, inplace=True)

# %% [markdown]
# #### Feature - quality_group

# %%
plt.figure(figsize=(10,10))
sns.countplot(y='quality_group', hue='status_group', data=df)
# Out:
# <AxesSubplot:xlabel='count', ylabel='quality_group'>

# %%
quality_df = df[(df['quality_group'] != 'good')]

plt.figure(figsize=(10,10))
sns.countplot(y='quality_group', hue='status_group', data=quality_df)
# Out:
# <AxesSubplot:xlabel='count', ylabel='quality_group'>

# %% [markdown]
# **OBSERVATION**
# 1. salty and uknown statuses have higher non-functioning than functioning counts

# %% [markdown]
# #### Feature - quantity

# %%
plt.figure(figsize=(10,10))
sns.countplot(y='quantity', hue='status_group', data=df)
# Out:
# <AxesSubplot:xlabel='count', ylabel='quantity'>

# %% [markdown]
# #### Feature - basin

# %%
plt.figure(figsize=(10,10))
sns.countplot(y='basin', hue='status_group', data=df)
# Out:
# <AxesSubplot:xlabel='count', ylabel='basin'>

# %% [markdown]
# #### Feature - scheme_management

# %%
plt.figure(figsize=(10,10))
sns.countplot(y='scheme_management', hue='status_group', data=df)
# Out:
# <AxesSubplot:xlabel='count', ylabel='scheme_management'>

# %% [markdown]
# #### Geographical Visualization

# %%
plt.figure(figsize=(20,15))
sns.scatterplot(x='longitude', y='latitude', hue='status_group', data=df)
# Out:
# <AxesSubplot:xlabel='longitude', ylabel='latitude'>

# %%
df.describe()
# Out:
#           amount_tsh     longitude      latitude   num_private   region_code  \
# count   48630.000000  48630.000000  4.863000e+04  48630.000000  48630.000000
# mean      357.870952     34.230648 -5.703317e+00      0.548262     14.684598
# std      2818.635008      6.309842  2.860211e+00     13.244462     17.199136
# min         0.000000      0.000000 -1.164944e+01      0.000000      1.000000
# 25%         0.000000     33.050844 -8.219467e+00      0.000000      5.000000
# 50%         0.000000     35.265112 -5.017793e+00      0.000000     12.000000
# 75%        50.000000     37.338478 -3.337886e+00      0.000000     17.000000
# max    250000.000000     40.323402 -2.000000e-08   1776.000000     99.000000
#
#        district_code    population  construction_year      well_age  \
# count   48630.000000  48630.000000       48630.000000  48630.000000
# mean        5.730393    175.389595        1332.920193     44.104668
# std         9.665276    471.061012         940.708415     40.767786
# min         0.000000      0.000000           0.000000      0.000000
# 25%         2.000000      0.000000           0.000000      8.000000
# 50%         3.000000     30.000000        1986.000000     27.000000
# 75%         5.000000    200.000000        2005.000000    100.000000
# max        80.000000  30500.000000        2013.000000    100.000000
#
#            altitude  month_recorded
# count  48630.000000    48630.000000
# mean     696.445157        4.318857
# std      698.813656        2.992206
# min      -90.000000        1.000000
# 25%        0.000000        2.000000
# 50%      452.000000        3.000000
# 75%     1332.000000        7.000000
# max     2770.000000       12.000000

# %%
df[df['longitude'] == 0]
# Out:
#        amount_tsh  longitude      latitude wpt_name  num_private  \
# 53            0.0        0.0 -2.000000e-08    Other            0
# 168           0.0        0.0 -2.000000e-08    Other            0
# 256           0.0        0.0 -2.000000e-08    Other            0
# 301           0.0        0.0 -2.000000e-08    Other            0
# 306           0.0        0.0 -2.000000e-08    Other            0
# ...           ...        ...           ...      ...          ...
# 59135         0.0        0.0 -2.000000e-08    Other            0
# 59158         0.0        0.0 -2.000000e-08    Other            0
# 59189         0.0        0.0 -2.000000e-08    Other            0
# 59295         0.0        0.0 -2.000000e-08    Other            0
# 59374         0.0        0.0 -2.000000e-08    Other            0
#
#                basin     region  region_code  district_code  population  ...  \
# 53     Lake Victoria     Mwanza           19              6           0  ...
# 168    Lake Victoria  Shinyanga           17              1           0  ...
# 256    Lake Victoria     Mwanza           19              6           0  ...
# 301    Lake Victoria     Mwanza           19              6           0  ...
# 306    Lake Victoria     Mwanza           19              6           0  ...
# ...              ...        ...          ...            ...         ...  ...
# 59135  Lake Victoria     Mwanza           19              6           0  ...
# 59158  Lake Victoria  Shinyanga           17              1           0  ...
# 59189  Lake Victoria  Shinyanga           17              1           0  ...
# 59295  Lake Victoria  Shinyanga           17              1           0  ...
# 59374  Lake Victoria  Shinyanga           17              1           0  ...
#
#       payment_type quality_group      quantity                source  \
# 53         unknown       unknown           dry           machine dbh
# 168          other          good      seasonal  rainwater harvesting
# 256      never pay       unknown           dry           machine dbh
# 301      never pay          good  insufficient           machine dbh
# 306      never pay          good  insufficient           machine dbh
# ...            ...           ...           ...                   ...
# 59135    never pay          good        enough          shallow well
# 59158    never pay          good        enough          shallow well
# 59189        other          good        enough          shallow well
# 59295    never pay          good        enough          shallow well
# 59374        other          good        enough          shallow well
#
#       source_class              waterpoint_type             status_group  \
# 53     groundwater  communal standpipe multiple           non functional
# 168        surface           communal standpipe               functional
# 256    groundwater                    hand pump           non functional
# 301    groundwater                    hand pump               functional
# 306    groundwater                    hand pump               functional
# ...            ...                          ...                      ...
# 59135  groundwater                    hand pump               functional
# 59158  groundwater                    hand pump               functional
# 59189  groundwater                    hand pump  functional needs repair
# 59295  groundwater                    hand pump  functional needs repair
# 59374  groundwater                    hand pump               functional
#
#       well_age altitude month_recorded
# 53         100        0              8
# 168        100        0              1
# 256        100        0              7
# 301        100        0              7
# 306        100        0              7
# ...        ...      ...            ...
# 59135      100        0              8
# 59158      100        0              7
# 59189      100        0              7
# 59295      100        0              7
# 59374      100        0             10
#
# [1326 rows x 27 columns]

# %%
df = df[df['longitude'] > 0]

# %%
plt.figure(figsize=(20,15))
sns.scatterplot(x='longitude', y='latitude', hue='status_group', data=df)
# Out:
# <AxesSubplot:xlabel='longitude', ylabel='latitude'>

# %% [markdown]
# # Modeling

# %%
df = df.replace({'status_group': 'functional'}, 1)
df = df.replace({'status_group': 'non functional'}, 2)
df = df.replace({'status_group': 'functional needs repair'}, 3)

# %% [markdown]
# ### Logistic Regression - Baseline

# %%
#splitting features and target
#creating dummy variables for categorical data
X = df.drop('status_group', axis=1)
X = pd.get_dummies(X, drop_first=True )

y = df['status_group']

# %%
#creating training and testing data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size= .25, random_state=2)

# %%
#scaling 
scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
lr_base = LogisticRegression(solver='sag', random_state=2, max_iter=1000)
lr_base_model = lr_base.fit(X_train_scaled, y_train)

# %%
#this function will return test and train classification reports and confusion matrix 
def report(classifier):
    #train classification report
    cr_train = print(classification_report(y_train, classifier.predict(X_train_scaled)))
    #test classification report
    cr_test= print(classification_report(y_test, classifier.predict(X_test_scaled)))
    #plotting confusion matrix
    plot_confusion_matrix(classifier, X_test_scaled, y_test,
            cmap=plt.cm.Blues)
    return cr_train, cr_test, plt.show()

# %%
report(lr_base)

# %% [markdown]
# ### Logistic Regression - Gridsearch Optimization (NOT PERFORMED)

# %%
# lr_v2 = LogisticRegression(solver='sag', random_state=2, max_iter=8000)

# weight_dict = {2: 1.5, 3:8}

# param_grid = {
#     'class_weight': [None, 'balanced', weight_dict],
#     'C': [1.0, 500, 1e12]
# }

# lr_v2_model = GridSearchCV(estimator = lr_v2, param_grid=param_grid, cv=2)
# lr_v2_model.fit(X_train_scaled, y_train)

# %% [markdown]
# **INTERPRETATION**
# - After 8000 iterations, the model has still not converged
# - I will be moving onto another model, as I have reason to believe logistic regression will perform quite poorly on this data due to its high dimensionality of categorical data

# %% [markdown]
# ## Decision Tree Baseline

# %%
dt_base = DecisionTreeClassifier()

dt_base_model = dt_base.fit(X_train_scaled, y_train)

# %%
report(dt_base_model)

# %%
print(dt_base.tree_.max_depth)

# %% [markdown]
# **INTERPRETATION**
# 1. Extremely Overfit. The model knows the training data completely

# %%
# %%script false --no-raise-error
# #takes about an hour to plot
#
# fig, axes = plt.subplots(nrows = 1,ncols = 1, figsize = (20,15), dpi=300)
# tree.plot_tree(dt_base,
#                feature_names = X.columns,
#                class_names=np.unique(y).astype('str'),
#                filled = True)
# plt.show()

# %% [markdown]
# **OBSERVATION**
# 1. The long tails confirm the high max depth - leading to overfitting

# %% [markdown]
# ## Decision Tree - v2

# %%
#functions same as 'report' but also returns best params from gridsearch
def report_grid(model):
    params = print(model.best_params_)
    cr_train = print(classification_report(y_train, model.predict(X_train_scaled)))
    cr_test = print(classification_report(y_test, model.predict(X_test_scaled)))
    plot_confusion_matrix(model, X_test_scaled, y_test,
                     cmap=plt.cm.Blues)
    return params, cr_train, cr_test, plt.show()

# %%
dt_v2 = DecisionTreeClassifier()

weight_dict = {1: 1, 2: 1.5, 3: 8}
weight_dict2 = {1: 0.5, 2: 3, 3: 10}
weight_dict3 = {1: 0.25, 2: 6, 3: 12}

param_grid = {
    'criterion' : ['gini', 'entropy'],
    'class_weight': [weight_dict, weight_dict2, weight_dict3, 'balanced'],
    'max_depth' : [10, 20, 30],
    'min_samples_split' : [1.0, 3, 5],
    'min_samples_leaf' : [10, 15, 30]
}

dt_v2_model = GridSearchCV(estimator = dt_v2, param_grid=param_grid, cv=3)
dt_v2_model.fit(X_train_scaled, y_train)

# %%
report_grid(dt_v2_model)

# %% [markdown]
# **INTERPRETATION**
# 1. 2/3 is worst case scenario (predicted non functional, but is actually in need of repair)
# 2. 3/1 is pretty bad (predicted in need of repair, but is actually working)

# %% [markdown]
# ## Decision Tree v3

# %%
dt_v3 = DecisionTreeClassifier(criterion= 'entropy')

weight_dict = {1: 1, 2: 1.5, 3: 8}
weight_dict2 = {1: 0.5, 2: 1.5, 3: 8}

param_grid = {
    'class_weight': [weight_dict, weight_dict2],
    'max_depth' : [25, 30, 35],
    'min_samples_split' : [3, 5],
    'min_samples_leaf' : [9, 10, 11]
}

dt_v3_model = GridSearchCV(estimator = dt_v3, param_grid=param_grid, cv=3)
dt_v3_model.fit(X_train_scaled, y_train)

# %%
report_grid(dt_v3_model)

# %% [markdown]
# ## Decision Tree v4

# %%
dt_v4 = DecisionTreeClassifier(criterion= 'entropy', max_depth=30)

weight_dict = {1: 1, 2: 1.5, 3: 8}
weight_dict2 = {1: 1, 2: 3, 3: 10}

param_grid = {
    'class_weight': [weight_dict, weight_dict2],
    'min_samples_split' : [2, 3],
    'min_samples_leaf' : [7, 8, 9]
}

dt_v4_model = GridSearchCV(estimator = dt_v4, param_grid=param_grid, cv=3)
dt_v4_model.fit(X_train_scaled, y_train)

# %%
report_grid(dt_v4_model)

# %% [markdown]
# ### Decision Tree - SMOTE

# %% [markdown]
# Thus far I have onl been dealing with class imbalance by adjusting 'class_weight' in gridsearch. While this is a valid technique, I am seeing little improvement. Using SMOTE to create new synthetic data, rather than simply giving more weight to the minority classes (2 and 3), might yield useful insight.

# %%
sm = SMOTE(random_state=2)

X_train_sm, y_train_sm = sm.fit_resample(X_train, y_train)

# %%
#scaling 
scaler = StandardScaler()

X_train_scaled_sm = scaler.fit_transform(X_train_sm)
X_test_scaled = scaler.transform(X_test)

# %%
def report_smote(model):
    cr_train = print(classification_report(y_train_sm, model.predict(X_train_scaled_sm)))
    cr_test = print(classification_report(y_test, model.predict(X_test_scaled)))
    plot_confusion_matrix(model, X_test_scaled, y_test,
                     cmap=plt.cm.Blues)
    return cr_train, cr_test, plt.show()

# %%
dt_smote_base = DecisionTreeClassifier()
dt_smote_base_model = dt_smote_base.fit(X_train_scaled_sm, y_train_sm)

# %%
report_smote(dt_smote_base)

# %%
print(dt_smote_base_model.tree_.max_depth)

# %% [markdown]
# ### Decision Tree - Smote(2)

# %%
def report_smote_grid(model):
    params = print(model.best_params_)
    cr_train = print(classification_report(y_train_sm, model.predict(X_train_scaled_sm)))
    cr_test = print(classification_report(y_test, model.predict(X_test_scaled)))
    plot_confusion_matrix(model, X_test_scaled, y_test,
                     cmap=plt.cm.Blues)
    return params, cr_train, cr_test, plt.show()

# %%
dt_smote_v2 = DecisionTreeClassifier()


param_grid = {
    'criterion' : ['gini', 'entropy'],
    'max_depth' : [10, 20, 25],
    'min_samples_split' : [1.0, 10, 20, 30],
    'min_samples_leaf' : [5, 10, 15]
}

dt_smote_v2_model = GridSearchCV(estimator = dt_smote_v2, param_grid=param_grid, cv=3)
dt_smote_v2_model.fit(X_train_scaled_sm, y_train_sm)

# %%
report_smote_grid(dt_smote_v2_model)

# %% [markdown]
# ### Decision Tree - SMOTE (3)

# %%
dt_smote_v4 = DecisionTreeClassifier(max_depth=25, min_samples_leaf=5, min_samples_split=10)

# %%
dt_smote_v4.fit(X_train_scaled_sm, y_train_sm)

# %%
report_smote(dt_smote_v4)

# %% [markdown]
# **INTERPRETATION**
# 1. 3 is still extremely overfit, but other classes are performing okay (still some overfitting)
# 2. Looking at overall performance across all classes, this is my best Decision Tree
# 3. Even after using SMOTE, my model is still bad at predicting 3 (the minority class).
#     - experimenting with class weights provided no significant breakthroughs
#     - Knowing this, there may be specific features that make predicting the minority class very difficult, so RandomForest may be able to address this

# %% [markdown]
# ## Random Forest - Baseline

# %%
forest_base = RandomForestClassifier()
forest_base_model = forest_base.fit(X_train_scaled, y_train)

# %%
report(forest_base)

# %%
print(classification_report(y_train, forest_base_model.predict(X_train_scaled)))

# %%
print(classification_report(y_test, forest_base_model.predict(X_test_scaled)))

# %%
max_depth = []
for classifier in forest_base_model:
    max_depth.append(classifier.tree_.max_depth)

# %%
stat.median(max_depth)

# %% [markdown]
# **INTERPRETATION**
# 1. Completely overfit, just like the Decision Tree basemodel
# 2. Max depth has increased from 30(decisiontree base model) to 40

# %% [markdown]
# ## Random Forest v2

# %% [markdown]
# **REASONING**
# 1. Thus far overfitting has been the largest obstacle for my DecisionTree models and my RandomForest basemodel
# 2. To address this, I am going to set the RandomForest parameters to values that will discourage overfitting (small max_depth, large min_sample_split, etc.)

# %%
# %%script false --no-raise-error
# #over 3 hours running no results
#
# forest_v2 = RandomForestClassifier()
#
# weight_dict = {1: 0.5, 2: 3, 3: 10}
# weight_dict2 = {1: 0.25, 2: 6, 3: 12}
#
# param_grid= {
#     'criterion': ['gini', 'entropy'],
#     'class_weight': [weight_dict, weight_dict2],
#     'max_depth': [25, 30, 35],
#     'min_samples_split': [10, 15, 20],
#     # trying to abide by the MSL should be at least 2xMSS
#     'min_samples_leaf': [20, 25, 30],
#     ,
#     #approx 6 seems to be the optimum number of features to consider
#     # https://www.analyticsvidhya.com/blog/2020/03/beginners-guide-random-forest-hyperparameter-tuning/
#
#
# }
#
# forest_v2_model = GridSearchCV(estimator = forest_v2, param_grid=param_grid, cv=3)
# forest_v2_model.fit(X_train_scaled, y_train)

# %% [markdown]
# # Merging 2 and 3

# %% [markdown]
# Thus far, performance for many of my models have been decent at predicting if a well is functioning, or not functioning, but has been terrible at correctly predicting if a well is functioning but needs repair
# 1. This can be attributed to the massive class imbalance
#     - A wide variety of different balancing measures (class_weights and SMOTE), and hyperparameter tuning for deciiontrees and randomforests have not been able to achieve a recall of over 50% for functioning-needs repair
# 2. To account for this I will merge 'nonfunctioning' and 'functioning-needs repair'
#     - Classifying funcitioning-needs repair as nonfunctioning is acceptable, as a repair team will be able to either fix a nonfunctioning well, or make repairs to a well that could  become nonfunctioning in the future

# %%
df_binary = df.replace({'status_group': 3}, 2)

# %%
df_binary['status_group'].value_counts()
# Out:
# 1    26127
# 2    21177
# Name: status_group, dtype: int64

# %%
fig, ax = plt.subplots(figsize=(10,5))


imbalance_plot= sns.countplot(ax=ax,
              x='status_group', 
              data=df_binary,
             color = 'orange')

plt.xticks([0,1], 
           ['Functional', 'Non-Functional'],
          fontsize=12)
plt.yticks(fontsize=12)
plt.xlabel(xlabel='Status', fontsize=14)
plt.ylabel(ylabel='Count', fontsize=14)
plt.title('Improved Class Imbalance', fontsize=15)
plt.savefig('images/class_imbalance_2');

# %% [markdown]
# This has alleviated the class imbalance tremendously

# %% [markdown]
# # EDA - Revisited

# %% [markdown]
# #### Geographic Visualiziation

# %%
plt.figure(figsize=(8,8))

#creating map plot 
tanz_map2 = plt.axes(projection=ccrs.PlateCarree())

#adding map features 
tanz_map2.add_feature(cfeature.LAND)
tanz_map2.add_feature(cfeature.OCEAN)
tanz_map2.add_feature(cfeature.COASTLINE)
tanz_map2.add_feature(cfeature.BORDERS, linestyle=':')
tanz_map2.add_feature(cfeature.LAKES, alpha=0.5)
tanz_map2.add_feature(cfeature.RIVERS)
tanz_map2.add_feature(cfeature.STATES.with_scale('10m'))

#creating scatter plot over map 
scatter = plt.scatter(df_binary['longitude'], df_binary['latitude'], alpha=0.5,
            c=df_binary['status_group'],
            cmap=plt.get_cmap("Set1"),
            transform=ccrs.PlateCarree())

#creating legend 
red_patch= mpatches.Patch(color='red', label='Functional')
grey_patch= mpatches.Patch(color='grey', label='Non-Functional')
plt.legend(handles=[red_patch, grey_patch])
plt.title('Functional vs Non-functional Map', fontsize=15)
plt.savefig('images/tanz_map');

# %%
plt.figure(figsize=(10,10))
sns.countplot(y='region', hue='status_group', data=df_binary)

plt.title('Classification by Region', fontsize=15)
plt.xticks(fontsize=12)
plt.xlabel('Region', fontsize=15)
plt.yticks(fontsize=12)
plt.ylabel('Count', fontsize=15)
plt.savefig('images/region')

# %%
df_regions = df_binary

#creating new dataframe with only regions where nonfunctional outweighs functional
nf_regions = ['Mara', 'Mtwara', 'Tabora', 'Rukwa', 'Kigoma', 'Lindi', 'Dodoma', 'Mbeya', 'Dar es Salaam']
for index,row in df_regions.iterrows():
    if row['region'] not in nf_regions:
        df_regions.drop(index, inplace=True)

# assigning each region a numerical value for plotting        
df_regions= df_regions.replace({'region': 'Mara'}, 1)
df_regions= df_regions.replace({'region': 'Mtwara'}, 2)
df_regions= df_regions.replace({'region': 'Tabora'}, 3)
df_regions= df_regions.replace({'region': 'Rukwa'}, 4)
df_regions= df_regions.replace({'region': 'Kigoma'}, 5)
df_regions= df_regions.replace({'region': 'Lindi'}, 6)
df_regions= df_regions.replace({'region': 'Dodoma'}, 7)
df_regions= df_regions.replace({'region': 'Mbeya'}, 8)
df_regions= df_regions.replace({'region': 'Dar es Salaam'}, 9)


#plotting
plt.figure(figsize=(8,8))

tanz_map3 = plt.axes(projection=ccrs.PlateCarree())

tanz_map3.add_feature(cfeature.LAND)
tanz_map3.add_feature(cfeature.OCEAN)
tanz_map3.add_feature(cfeature.COASTLINE)
tanz_map3.add_feature(cfeature.BORDERS, linestyle=':')
tanz_map3.add_feature(cfeature.LAKES, alpha=0.5)
tanz_map3.add_feature(cfeature.RIVERS)
tanz_map3.add_feature(cfeature.STATES.with_scale('10m'))

scatter = plt.scatter(df_regions['longitude'], df_regions['latitude'], alpha=0.5,
            c=df_regions['region'],
            cmap=plt.get_cmap("Set1"),
            transform=ccrs.PlateCarree())

#creating corresponding legend 
red_patch= mpatches.Patch(color='red', label='Mara')
grey_patch= mpatches.Patch(color='grey', label='Dar es Salaam')
yellow_patch = mpatches.Patch(color='yellow', label='Lindi')
blue_patch = mpatches.Patch(color='blue', label='Mwara')
brown_patch= mpatches.Patch(color='brown', label='Dodoma')
green_patch= mpatches.Patch(color='green', label='Tabora')
orange_patch= mpatches.Patch(color='orange', label='Kigoma')
purple_patch= mpatches.Patch(color='purple', label='Rukwa/Katavi')
pink_patch=mpatches.Patch(color='pink', label='Mbeya')
plt.legend(handles=[red_patch, grey_patch, yellow_patch, purple_patch, blue_patch,
                   brown_patch, green_patch, orange_patch, pink_patch]);

plt.title('Regions: Non-functional > Functional', fontsize=15)
plt.savefig('images/region_map');

# %%
df_binary = df.replace({'status_group': 'functional needs repair'}, 'non functional')

# %%
df_binary = df
df_binary = df.replace({'status_group': 3}, 2)

# %%
df_binary.status_group.value_counts()
# Out:
# 1    26127
# 2    21177
# Name: status_group, dtype: int64

# %% [markdown]
# #### Feature- well_age

# %%
plt.figure(figsize=(10,10))
sns.countplot(y='well_age', hue='status_group', data=df_binary)
# Out:
# <AxesSubplot:xlabel='count', ylabel='well_age'>

# %%
df_age = df_binary[(df_binary['well_age']<100) & (df_binary['well_age']>24)]

# %%
plt.figure(figsize=(10,10))
sns.countplot(y='well_age', hue='status_group', data=df_age)

plt.title('Well_Age: Non-functional > Functional ', fontsize=15)
plt.xticks(fontsize=12)
plt.xlabel('Count', fontsize=15)
plt.yticks(fontsize=12)
plt.ylabel('Age', fontsize=15)
# Out:
# Text(0, 0.5, 'Age')

# %% [markdown]
# **OBSERVATION**
# 1. Most ages above 25 have nonfunctioning outweighting functioning

# %% [markdown]
# #### Feature - Numerical

# %%
df_binary.groupby('status_group').median()
# Out:
#               amount_tsh  longitude  latitude  num_private  region_code  \
# status_group
# 1                    0.0  35.386345 -4.989844            0           11
# 2                    0.0  35.370834 -5.418657            0           12
#
#               district_code  population  construction_year  well_age  \
# status_group
# 1                         3          45               1996        17
# 2                         3           1               1980        33
#
#               altitude  month_recorded
# status_group
# 1                  838               3
# 2                  340               3

# %% [markdown]
# **OBSERVATION**
# 1. Functional wells tend to be at slightly higher altitudes than nonfuctioning
# 2. Functional wells tend to have higher populations
#     - This could make sense as there may be more resources and priorities to maintain these wells
# 3. Further confirmation that older wells tend to be less functional
# 4. considering amount_tsh is a measure of static head (measured in distance), a value of 0.0 probably indicates that there is too much filler data for this feature to be very useful

# %% [markdown]
# #### Feature - quantity

# %%
plt.figure(figsize=(10,10))
sns.countplot(y='quantity', hue='status_group', data=df_binary)

plt.title('Water Quantity', fontsize=15)
plt.xticks(fontsize=12)
plt.xlabel('Count', fontsize=15)
plt.yticks(fontsize=12)
plt.ylabel('Quantity', fontsize=15)
# Out:
# Text(0, 0.5, 'Quantity')

# %% [markdown]
# **OBSERVATION**
# 1. the quantity "insufficient" is nearing equal parts functioning and non-functioning
#     - It is probably safe to reason that before a well achieves the quantity 'dry' it achieves the quantity 'insufficient'

# %%
quality_df = df_binary[(df_binary['quality_group'] != 'good')]

plt.figure(figsize=(10,10))
sns.countplot(y='quality_group', hue='status_group', data=quality_df)

plt.title('Water Quality ', fontsize=15)
plt.xticks(fontsize=12)
plt.xlabel('Count', fontsize=15)
plt.yticks(fontsize=12)
plt.ylabel('Quality', fontsize=15)
# Out:
# Text(0, 0.5, 'Quality')

# %%
plt.figure(figsize=(10,10))
sns.countplot(x='month_recorded', hue='status_group', data=df_binary)

plt.xticks(ticks = range(0,12),
           labels = ['Jan', 'Feb', 'March', 'April', 'May', 'June', 'July', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'], 
           fontsize=12)

plt.title('Recorded Wells by Month', fontsize=15)
plt.xticks(fontsize=12)
plt.xlabel('Month Recorded', fontsize=15)
plt.yticks(fontsize=12)
plt.ylabel('Count', fontsize=15)
# Out:
# Text(0, 0.5, 'Count')

# %%
rainfall = [2.5, 3, 6.25, 12, 8.75, 1, .75, 1, 1, 1.5, 3.5, 3.25]
# SOURCE: https://www.safaribookings.com/tanzania/climate

# %%
fig, ax1 = plt.subplots(figsize=(12,6))

ax2 = ax1.twinx()
ax2=sns.lineplot(data = rainfall, marker='o', sort = False, ax=ax1)
ax2.set_ylabel('Average Rainfall (Inches)', fontsize=14)
ax2.set_xlabel('Month Recorded', fontsize=14)

sns.countplot(x='month_recorded', hue='status_group', data=df_binary)

plt.xticks(ticks = range(0,12),
           labels = ['Jan', 'Feb', 'March', 'April', 'May', 'June', 'July', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'], 
           fontsize=12);
plt.title('Wells Recorded by Month & Monthly Rainfall', fontsize=15)
plt.xticks(fontsize=12)
plt.xlabel('Month Recorded', fontsize=15)
plt.yticks(fontsize=12)
plt.ylabel('Well Count', fontsize=15)
plt.savefig('images/month_rain.png')

# %% [markdown]
# **OBSERVATION**
# 1. Months when non-functioning outweight functioning
#     1. January
#     2. April
#     3. July

# %% [markdown]
# # MODELING

# %%
#splitting features and target
#creating dummy variables for categorical data
X = df_binary.drop('status_group', axis=1)
X = pd.get_dummies(X, drop_first=True )

y = df_binary['status_group']

#creating training and testing data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size= .25, random_state=42)


#scaling 
scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# ## Decision Tree - Baseline

# %%
dt_base = DecisionTreeClassifier()

dt_base_model = dt_base.fit(X_train_scaled, y_train)

# %%
# fig, axes = plt.subplots(nrows = 1,ncols = 1, figsize = (3,3), dpi=300)
# tree.plot_tree(dt_base,
#                feature_names = X.columns, 
#                class_names=np.unique(y).astype('str'),
#                filled = True)
# plt.show()

# %%
print(classification_report(y_train, dt_base.predict(X_train_scaled)))
# Out:
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00     19593
#            2       1.00      1.00      1.00     15885
#
#     accuracy                           1.00     35478
#    macro avg       1.00      1.00      1.00     35478
# weighted avg       1.00      1.00      1.00     35478

# %%
dt_base.tree_.max_depth
# Out:
# 40

# %%
report(dt_base_model)
# Out:
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00     19593
#            2       1.00      1.00      1.00     15885
#
#     accuracy                           1.00     35478
#    macro avg       1.00      1.00      1.00     35478
# weighted avg       1.00      1.00      1.00     35478
#
#               precision    recall  f1-score   support
#
#            1       0.81      0.81      0.81      6534
#            2       0.76      0.76      0.76      5292
#
#     accuracy                           0.79     11826
#    macro avg       0.78      0.78      0.78     11826
# weighted avg       0.79      0.79      0.79     11826
# (None, None, None)

# %% [markdown]
# **INTERPRETATION**
# 1. Training is completely overfit (to be exptected)
# 2. FP and FN are nearly identical... does this mean the model is guessing 50/50?

# %% [markdown]
# ## Decision Tree v2 (Gridsearch)

# %%
dt_v2 = DecisionTreeClassifier()

param_grid = {
    'criterion': ['gini', 'entropy'],
    'class_weight': ['balanced', None],
    'max_depth' : [10, 20, 30],
    'min_samples_split': [5, 10, 15],
    'min_samples_leaf': [10, 20, 30],
}

dt_v2_model = GridSearchCV(estimator = dt_v2, param_grid=param_grid, cv=3)
dt_v2_model.fit(X_train_scaled, y_train)
# Out:
# GridSearchCV(cv=3, estimator=DecisionTreeClassifier(),
#              param_grid={'class_weight': ['balanced', None],
#                          'criterion': ['gini', 'entropy'],
#                          'max_depth': [10, 20, 30],
#                          'min_samples_leaf': [10, 20, 30],
#                          'min_samples_split': [5, 10, 15]})

# %%
report_grid(dt_v2_model)
# Out:
# {'class_weight': None, 'criterion': 'gini', 'max_depth': 20, 'min_samples_leaf': 10, 'min_samples_split': 15}
#               precision    recall  f1-score   support
#
#            1       0.85      0.91      0.88     19593
#            2       0.88      0.80      0.84     15885
#
#     accuracy                           0.86     35478
#    macro avg       0.86      0.86      0.86     35478
# weighted avg       0.86      0.86      0.86     35478
#
#               precision    recall  f1-score   support
#
#            1       0.79      0.85      0.82      6534
#            2       0.79      0.73      0.76      5292
#
#     accuracy                           0.79     11826
#    macro avg       0.79      0.79      0.79     11826
# weighted avg       0.79      0.79      0.79     11826
# (None, None, None, None)

# %% [markdown]
# **INTERPRETATION**
# 1. Accuracy remains the same as basemodel
# 2. recall for Functioning improved
# 3. recall for Nonfunctioning has dropped by 4%
# 4. False Negatives are higher - worst case

# %% [markdown]
# ## Decision Tree v3 - LAST TREE

# %% [markdown]
# **INTENTIONS**
# 1. I will be weighting 'nonfunctioning' slightly more and 'functioning' slightly less to see if FN will drop

# %%
dt_v3 = DecisionTreeClassifier(criterion='gini', max_depth=20, min_samples_split=10)

weight_dict = {1: 0.75, 2: 1.25}
weight_dict2= {1: 0.9, 2: 1.1}

param_grid = {
    'class_weight': [weight_dict, weight_dict2],
    'min_samples_leaf': [5, 7, 10],
}

dt_v3_model = GridSearchCV(estimator = dt_v3, param_grid=param_grid, cv=3)
dt_v3_model.fit(X_train_scaled, y_train)
# Out:
# GridSearchCV(cv=3,
#              estimator=DecisionTreeClassifier(max_depth=20,
#                                               min_samples_split=10),
#              param_grid={'class_weight': [{1: 0.75, 2: 1.25}, {1: 0.9, 2: 1.1}],
#                          'min_samples_leaf': [5, 7, 10]})

# %%
report_grid(dt_v3_model)
# Out:
# {'class_weight': {1: 0.9, 2: 1.1}, 'min_samples_leaf': 5}
#               precision    recall  f1-score   support
#
#            1       0.89      0.91      0.90     19593
#            2       0.88      0.86      0.87     15885
#
#     accuracy                           0.89     35478
#    macro avg       0.89      0.89      0.89     35478
# weighted avg       0.89      0.89      0.89     35478
#
#               precision    recall  f1-score   support
#
#            1       0.80      0.82      0.81      6534
#            2       0.77      0.75      0.76      5292
#
#     accuracy                           0.79     11826
#    macro avg       0.79      0.78      0.78     11826
# weighted avg       0.79      0.79      0.79     11826
# (None, None, None, None)

# %% [markdown]
# **INTERPRETATION**
# 1. Adjusting class weights slightly in favor of nonfunctional had a very minimal decrease in FN
# 2. Recall for nonfunctinoal has increased by 3%, sacrificing 3% recall for functional

# %% [markdown]
# ### Best Decision Tree = dt_v3_model
# - Accuracy : 79%
# - Nonfunctional Recall : 75%
# - Nonfunctional F1: 76%

# %% [markdown]
# # Random Forest - Baseline

# %% [markdown]
# 1. I am expecting RandomForest models to have an improvement in performance due to ###########
# 2. Viewing feature importance will be a helpful insight

# %%
forest_base = RandomForestClassifier()
forest_base_model = forest_base.fit(X_train_scaled, y_train)

# %%
report(forest_base_model)
# Out:
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00     19593
#            2       1.00      1.00      1.00     15885
#
#     accuracy                           1.00     35478
#    macro avg       1.00      1.00      1.00     35478
# weighted avg       1.00      1.00      1.00     35478
#
#               precision    recall  f1-score   support
#
#            1       0.82      0.86      0.84      6534
#            2       0.82      0.77      0.79      5292
#
#     accuracy                           0.82     11826
#    macro avg       0.82      0.81      0.82     11826
# weighted avg       0.82      0.82      0.82     11826
# (None, None, None)

# %%
max_depth_base = []
for classifier in forest_base_model:
    max_depth_base.append(classifier.tree_.max_depth)

stat.median(max_depth_base)
# Out:
# 41.0

# %%
def plot_feature_importances_base(model):
    n_features = X_train.shape[1]
    plt.figure(figsize=(20,20))
    plt.barh(range(n_features), model.feature_importances_, align='center') 
    plt.yticks(np.arange(n_features), X_train.columns.values) 
    plt.xlabel('Feature importance')
    plt.ylabel('Feature')

# %%
plot_feature_importances_base(forest_base_model)

# %% [markdown]
# **INTERPRETATION**
# 1. Performance is nearly identical to the DecisionTree basemodel
#     - Completely overfit
#     - this gives me little faith that RandomForest will help provide optimal results

# %% [markdown]
# ## RandomForest v2 (Gridsearch)

# %%
forest_v2 = RandomForestClassifier()

param_grid= {
    'criterion': ['gini', 'entropy'],
    'class_weight': ['balanced', None],
    'max_depth': [25, 30, 35], 
    'min_samples_split': [10, 15, 20],
    'min_samples_leaf': [20, 25, 30],    
}

forest_v2_model = GridSearchCV(estimator = forest_v2, param_grid=param_grid, cv=3)
forest_v2_model.fit(X_train_scaled, y_train)
# Out:
# GridSearchCV(cv=3, estimator=RandomForestClassifier(),
#              param_grid={'class_weight': ['balanced', None],
#                          'criterion': ['gini', 'entropy'],
#                          'max_depth': [25, 30, 35],
#                          'min_samples_leaf': [20, 25, 30],
#                          'min_samples_split': [10, 15, 20]})

# %%
report_grid(forest_v2_model)
# Out:
# {'class_weight': None, 'criterion': 'gini', 'max_depth': 35, 'min_samples_leaf': 20, 'min_samples_split': 10}
#               precision    recall  f1-score   support
#
#            1       0.79      0.90      0.84     19593
#            2       0.85      0.71      0.77     15885
#
#     accuracy                           0.81     35478
#    macro avg       0.82      0.80      0.81     35478
# weighted avg       0.82      0.81      0.81     35478
#
#               precision    recall  f1-score   support
#
#            1       0.77      0.87      0.82      6534
#            2       0.81      0.68      0.74      5292
#
#     accuracy                           0.79     11826
#    macro avg       0.79      0.78      0.78     11826
# weighted avg       0.79      0.79      0.78     11826
# (None, None, None, None)

# %% [markdown]
# **INTERPRETATION**
# 1. Surprisingly, this model does not produce much better results than the best decisiontree model
#     - 79% accuracy for both
# 2. Most importantly, FN are much worse
#     - nonfunctional recall has dropped 8%

# %%
def plot_feature_importances(model):
    n_features = X_train.shape[1]
    plt.figure(figsize=(20,20))
    plt.barh(range(n_features), model.best_estimator_.feature_importances_, align='center') 
    plt.yticks(np.arange(n_features), X_train.columns.values) 
    plt.xlabel('Feature importance')
    plt.ylabel('Feature')

# %%
plot_feature_importances(forest_v2_model)

# %% [markdown]
# ## Random Forest v3

# %% [markdown]
# **INTENTIONS**
# 1. All models have been favoring class_weight = None, so I am going to force weighted scale in favor of nonfunctional to see if FN go down

# %%
forest_v3 = RandomForestClassifier(criterion='entropy', 
                                   max_depth=35, 
                                   class_weight={1: 0.75, 2:1.25}, 
                                   min_samples_split=15,  )

param_grid= {
    'min_samples_leaf': [10, 15, 20],    
}

forest_v3_model = GridSearchCV(estimator = forest_v3, param_grid=param_grid, cv=3)
forest_v3_model.fit(X_train_scaled, y_train)
# Out:
# GridSearchCV(cv=3,
#              estimator=RandomForestClassifier(class_weight={1: 0.75, 2: 1.25},
#                                               criterion='entropy', max_depth=35,
#                                               min_samples_split=15),
#              param_grid={'min_samples_leaf': [10, 15, 20]})

# %%
report_grid(forest_v3_model)
# Out:
# {'min_samples_leaf': 10}
#               precision    recall  f1-score   support
#
#            1       0.88      0.79      0.83     19593
#            2       0.77      0.87      0.82     15885
#
#     accuracy                           0.82     35478
#    macro avg       0.83      0.83      0.82     35478
# weighted avg       0.83      0.82      0.83     35478
#
#               precision    recall  f1-score   support
#
#            1       0.85      0.75      0.80      6534
#            2       0.73      0.84      0.78      5292
#
#     accuracy                           0.79     11826
#    macro avg       0.79      0.79      0.79     11826
# weighted avg       0.80      0.79      0.79     11826
# (None, None, None, None)

# %% [markdown]
# **INTERPRETATION**
# 1. Forcing the class weight significantly reduced FN
#     - the count of FN and FP have essentially switched from the previous model , which is a small step in the right dirrection
#     - curious to see how a Decisiontree would handle weight coercion

# %%
plot_feature_importances(forest_v3_model)

# %% [markdown]
# # RandomForest v4

# %% [markdown]
# **INTENTIONS**
# 1. Keeping the forced weight, I want to find the optimal parameters surrounding it

# %%
forest_v4 = RandomForestClassifier(max_depth=35, class_weight={1: 0.75, 2:1.25})

param_grid= {
    'criterion': ['gini', 'entropy'],
    'min_samples_split': [10, 15, 20],
    'min_samples_leaf': [20, 25, 30],    
}

forest_v4_model = GridSearchCV(estimator = forest_v4, param_grid=param_grid, cv=3)
forest_v4_model.fit(X_train_scaled, y_train)
# Out:
# GridSearchCV(cv=3,
#              estimator=RandomForestClassifier(class_weight={1: 0.75, 2: 1.25},
#                                               max_depth=35),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'min_samples_leaf': [20, 25, 30],
#                          'min_samples_split': [10, 15, 20]})

# %%
report(forest_v4_model)
# Out:
#               precision    recall  f1-score   support
#
#            1       0.87      0.75      0.80     19593
#            2       0.73      0.86      0.79     15885
#
#     accuracy                           0.80     35478
#    macro avg       0.80      0.80      0.80     35478
# weighted avg       0.81      0.80      0.80     35478
#
#               precision    recall  f1-score   support
#
#            1       0.84      0.71      0.77      6534
#            2       0.70      0.84      0.76      5292
#
#     accuracy                           0.77     11826
#    macro avg       0.77      0.78      0.77     11826
# weighted avg       0.78      0.77      0.77     11826
# (None, None, None)

# %% [markdown]
# **INTERPRETATION**
# 1. Recall has increased 1% as FN have dropped slightly from the previous model
# 2. FP continue to rise at a larger rate than FN are falling
# 3. I consider the performance of this model slightly worse than the previous

# %%
plot_feature_importances(forest_v4_model)

# %% [markdown]
# # XGBoost - Baseline

# %%
xgb_base = XGBClassifier()
xgb_base_model = xgb_base.fit(X_train_scaled, y_train)

# %%
report(xgb_base_model)
# Out:
#               precision    recall  f1-score   support
#
#            1       0.85      0.93      0.88     19593
#            2       0.90      0.79      0.84     15885
#
#     accuracy                           0.87     35478
#    macro avg       0.87      0.86      0.86     35478
# weighted avg       0.87      0.87      0.87     35478
#
#               precision    recall  f1-score   support
#
#            1       0.80      0.88      0.84      6534
#            2       0.83      0.72      0.77      5292
#
#     accuracy                           0.81     11826
#    macro avg       0.81      0.80      0.80     11826
# weighted avg       0.81      0.81      0.81     11826
# (None, None, None)

# %%
#for README

# fig, ax = plt.subplots(figsize=(7,7))

# plot_confusion_matrix(xgb_base_model, 
#                       X_test_scaled, 
#                       y_test,
#                       ax=ax,
#                      cmap=plt.cm.Blues)
# plt.xticks([0,1], ['F', 'NF'], fontsize=15)
# plt.xlabel('Predicted Lable', fontsize=15)
# plt.ylabel('True Lable', fontsize=15)
# plt.yticks([0,1], ['F', 'NF'], fontsize=15)
# plt.title('XGboost Confusion Matrix', fontsize=15)
# plt.savefig('images/base_cm')
# plt.show()

# %% [markdown]
# **INTERPRETATION**
# 1. The basemodel has achieved much better results than many of my attempts to omptimize DT and RF
# 2. Perhaps adjusting weights will once again force the algorithm to predict less FN

# %% [markdown]
# ## XGBoost v2

# %%
xgb_v2 = XGBClassifier()

param_grid = {
    'learning_rate' : [0.1, 0.2],
    'max_depth': [4, 6, 8],
    'min_child_weight': [1, 2],
    'sub_sample': [0.5, 0.7],
    
}

xgb_v2_model = GridSearchCV(estimator = xgb_v2, param_grid=param_grid, cv=3)
xgb_v2_model.fit(X_train_scaled, y_train)
# Out:
# [12:57:01] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:57:07] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:57:11] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:57:16] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:57:21] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:57:26] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:57:32] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:57:37] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:57:42] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:57:47] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:57:52] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:57:57] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:58:02] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:58:09] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:58:16] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:58:24] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:58:31] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:58:38] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:58:45] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:58:53] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:59:01] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:59:08] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
# [12:59:15] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:59:22] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:59:29] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:59:38] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:59:47] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:59:57] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:00:08] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:00:17] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:00:27] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:00:36] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:00:46] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:00:57] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:01:12] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:01:25] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:01:38] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:01:44] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:01:53] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:02:00] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:02:06] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:02:11] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:02:17] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:02:22] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
# [13:02:27] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:02:32] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:02:37] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:02:42] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:02:48] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:02:55] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:03:02] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:03:11] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:03:20] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:03:31] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:03:39] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:03:47] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:03:54] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:04:02] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:04:10] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:04:20] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:04:35] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:04:49] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:05:11] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:05:33] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:05:43] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:05:53] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
# [13:06:02] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:06:12] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:06:21] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:06:31] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:06:40] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:06:49] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:06:59] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
# GridSearchCV(cv=3,
#              estimator=XGBClassifier(base_score=None, booster=None,
#                                      colsample_bylevel=None,
#                                      colsample_bynode=None,
#                                      colsample_bytree=None, gamma=None,
#                                      gpu_id=None, importance_type='gain',
#                                      interaction_constraints=None,
#                                      learning_rate=None, max_delta_step=None,
#                                      max_depth=None, min_child_weight=None,
#                                      missing=nan, monotone_constraints=None,
#                                      n_estimators=100, n_jobs=None,
#                                      num_parallel_tree=None, random_state=None,
#                                      reg_alpha=None, reg_lambda=None,
#                                      scale_pos_weight=None, subsample=None,
#                                      tree_method=None, validate_parameters=None,
#                                      verbosity=None),
#              param_grid={'learning_rate': [0.1, 0.2], 'max_depth': [4, 6, 8],
#                          'min_child_weight': [1, 2], 'sub_sample': [0.5, 0.7]})

# %%
report_grid(xgb_v2_model)
# Out:
# {'learning_rate': 0.2, 'max_depth': 8, 'min_child_weight': 1, 'sub_sample': 0.5}
#               precision    recall  f1-score   support
#
#            1       0.87      0.94      0.90     19593
#            2       0.92      0.82      0.87     15885
#
#     accuracy                           0.89     35478
#    macro avg       0.89      0.88      0.89     35478
# weighted avg       0.89      0.89      0.89     35478
#
#               precision    recall  f1-score   support
#
#            1       0.80      0.88      0.84      6534
#            2       0.83      0.73      0.78      5292
#
#     accuracy                           0.81     11826
#    macro avg       0.82      0.80      0.81     11826
# weighted avg       0.81      0.81      0.81     11826
# (None, None, None, None)

# %% [markdown]
# **INTERPRETATION**
# 1. Barely any difference
# 2. While these results are 'good', they are not optimized for my business problem
#     - going to use scale_pos_weight to attempt this

# %%
xgb_v3 = XGBClassifier(sub_sample=0.5, scale_pos_weight=2, random_state=42)


param_grid = {
    'max_depth': [8, 10, 12],
    'learning_rate': [0.1, 0.075, 0.05]
}

xgb_v3_model = GridSearchCV(estimator = xgb_v3, param_grid=param_grid, cv=3)
xgb_v3_model.fit(X_train_scaled, y_train)
# Out:
# [13:07:14] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:07:23] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:07:33] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:07:42] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:07:54] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:08:07] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:08:22] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:08:40] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:09:07] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:09:24] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:09:36] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:09:47] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:09:58] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:10:12] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:10:26] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:10:45] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:11:01] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:11:17] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:11:33] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:11:44] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:11:54] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:12:05] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
# [13:12:18] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:12:31] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:12:46] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:13:00] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:13:15] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:13:36] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
# GridSearchCV(cv=3,
#              estimator=XGBClassifier(base_score=None, booster=None,
#                                      colsample_bylevel=None,
#                                      colsample_bynode=None,
#                                      colsample_bytree=None, gamma=None,
#                                      gpu_id=None, importance_type='gain',
#                                      interaction_constraints=None,
#                                      learning_rate=None, max_delta_step=None,
#                                      max_depth=None, min_child_weight=None,
#                                      missing=nan, monotone_constraints=None,
#                                      n_estimators=100, n_jobs=None,
#                                      num_parallel_tree=None, random_state=42,
#                                      reg_alpha=None, reg_lambda=None,
#                                      scale_pos_weight=2, sub_sample=0.5,
#                                      subsample=None, tree_method=None,
#                                      validate_parameters=None, verbosity=None),
#              param_grid={'learning_rate': [0.1, 0.075, 0.05],
#                          'max_depth': [8, 10, 12]})

# %%
report_grid(xgb_v3_model)
# Out:
# {'learning_rate': 0.1, 'max_depth': 12}
#               precision    recall  f1-score   support
#
#            1       0.96      0.89      0.92     19593
#            2       0.87      0.95      0.91     15885
#
#     accuracy                           0.92     35478
#    macro avg       0.92      0.92      0.92     35478
# weighted avg       0.92      0.92      0.92     35478
#
#               precision    recall  f1-score   support
#
#            1       0.85      0.78      0.81      6534
#            2       0.75      0.83      0.79      5292
#
#     accuracy                           0.80     11826
#    macro avg       0.80      0.81      0.80     11826
# weighted avg       0.81      0.80      0.80     11826
# (None, None, None, None)

# %% [markdown]
# **INTERPRETATION**
# 1. Adjusting scale_pos_weight has made the model less likely to predict FN
# 2. There still seems to be some overfitting

# %%
xgb_v4 = XGBClassifier(sub_sample=0.5, scale_pos_weight=2, learning_rate=0.2, random_state=42)


param_grid = {
    'sub_sample' : [0.5, 0.4],
    'max_depth': [6, 7, 8]
    
}

xgb_v4_model = GridSearchCV(estimator = xgb_v4, param_grid=param_grid, cv=3)
xgb_v4_model.fit(X_train_scaled, y_train)
# Out:
# [13:13:59] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:14:06] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:14:13] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:14:21] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:14:30] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:14:39] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:14:46] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:14:56] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:15:06] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:15:14] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:15:23] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:15:31] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:15:40] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:15:49] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:15:58] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:16:08] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:16:17] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:16:26] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:16:36] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
# GridSearchCV(cv=3,
#              estimator=XGBClassifier(base_score=None, booster=None,
#                                      colsample_bylevel=None,
#                                      colsample_bynode=None,
#                                      colsample_bytree=None, gamma=None,
#                                      gpu_id=None, importance_type='gain',
#                                      interaction_constraints=None,
#                                      learning_rate=0.2, max_delta_step=None,
#                                      max_depth=None, min_child_weight=None,
#                                      missing=nan, monotone_constraints=None,
#                                      n_estimators=100, n_jobs=None,
#                                      num_parallel_tree=None, random_state=42,
#                                      reg_alpha=None, reg_lambda=None,
#                                      scale_pos_weight=2, sub_sample=0.5,
#                                      subsample=None, tree_method=None,
#                                      validate_parameters=None, verbosity=None),
#              param_grid={'max_depth': [6, 7, 8], 'sub_sample': [0.5, 0.4]})

# %%
report_grid(xgb_v4_model)
# Out:
# {'max_depth': 8, 'sub_sample': 0.5}
#               precision    recall  f1-score   support
#
#            1       0.94      0.85      0.89     19593
#            2       0.83      0.93      0.88     15885
#
#     accuracy                           0.88     35478
#    macro avg       0.88      0.89      0.88     35478
# weighted avg       0.89      0.88      0.88     35478
#
#               precision    recall  f1-score   support
#
#            1       0.85      0.76      0.81      6534
#            2       0.74      0.84      0.79      5292
#
#     accuracy                           0.80     11826
#    macro avg       0.80      0.80      0.80     11826
# weighted avg       0.80      0.80      0.80     11826
# (None, None, None, None)

# %%
fig, ax = plt.subplots(figsize=(7,7))

plot_confusion_matrix(xgb_v4_model, 
                      X_test_scaled, 
                      y_test,
                      ax=ax,
                     cmap=plt.cm.Blues)
plt.xticks([0,1], ['F', 'NF'], fontsize=15)
plt.xlabel('Predicted Lable', fontsize=15)
plt.ylabel('True Lable', fontsize=15)
plt.yticks([0,1], ['F', 'NF'], fontsize=15)
plt.title('XGboost Confusion Matrix', fontsize=15)
plt.savefig('images/final_cm')
plt.show()

# %%
plot_feature_importances(xgb_v4_model)

# %% [markdown]
# **INTERPRETATION**
# 1. There may be only slightly less overfitting as the test accuracy remains the same, but the train accuracy has fallen by 5%
# 2. FN slightly lower than previous model
# 3. Compared to the best RandomForest model, recall, f1-score, and accuracy have all improved by 1%

# %% [markdown]
# # FINAL MODEL

# %%
report_grid(xgb_v4_model)
# Out:
# {'max_depth': 8, 'sub_sample': 0.5}
#               precision    recall  f1-score   support
#
#            1       0.94      0.85      0.89     19593
#            2       0.83      0.93      0.88     15885
#
#     accuracy                           0.88     35478
#    macro avg       0.88      0.89      0.88     35478
# weighted avg       0.89      0.88      0.88     35478
#
#               precision    recall  f1-score   support
#
#            1       0.85      0.76      0.81      6534
#            2       0.74      0.84      0.79      5292
#
#     accuracy                           0.80     11826
#    macro avg       0.80      0.80      0.80     11826
# weighted avg       0.80      0.80      0.80     11826
# (None, None, None, None)

# %% [markdown]
# # CONCLUSION

# %% [markdown]
# ### Recommendations

# %% [markdown]
# **Monitoring:**
# - Regions in which NF wells outnumber F should be monitored with heightened attention:
#     - Mara, Mtwara, Tabora, Rukwa, Kigoma, Lindi, Dodoma, Mbeya, Dar es Salaam
# - Monitoring efforts should increase during months in which NF wells outnumber F:
#     - January, April, July
#
# **Alerts:**
# - Send warning when a well ages over 24 years
#     - Suggest more frequent checks
# - Send warning anytime a well’s water quantity is reported as ‘insufficient’ and/or ‘dry’
#     - Suggest checking
# - Send warning in June when dry season begins
#     - Suggest more frequent checks through October

# %% [markdown]
# ### Going Forward

# %% [markdown]
# - Conduct PCA during initial data cleaning in order to reduce dimensionality in a more calculated manner
# - Advocate for additional  metrics to be used to describe “Water Quality”
# - Advocate for higher recording rates during dry season
