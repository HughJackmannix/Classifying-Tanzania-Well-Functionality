# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import re
import folium

from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV

from sklearn.linear_model import LogisticRegression

from sklearn.tree import DecisionTreeClassifier
from sklearn import tree
from sklearn import metrics
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report 
from sklearn.metrics import plot_confusion_matrix

from sklearn.ensemble import BaggingClassifier, RandomForestClassifier

from sklearn.svm import SVC

from imblearn.over_sampling import SMOTE

# %%
sns.set_style('darkgrid')

# %%
df_values = pd.read_csv('data/values.csv')
df_labels = pd.read_csv('data/labels.csv')

df = pd.merge(df_values, df_labels, on='id')

# %% [markdown]
# # Business Problem

# %% [markdown]
# A nonprofit wants to improve access to water across Tanzania. To do so, the nonprofit wants to be able to send alerts to the entities in charge of an individual to check the status of said well. These alerts will be sent when a well is deemed 'in need of repair' or 'non-functioning'. With this goal in mind, the nonprofit needs an algorithm that can accurately predict when the wells should be checked.

# %% [markdown]
# # SCRUBBING

# %%
df.drop('id', axis=1, inplace=True)

# %%
df.isna().sum()
# Out:
# amount_tsh                   0
# date_recorded                0
# funder                    3635
# gps_height                   0
# installer                 3655
# longitude                    0
# latitude                     0
# wpt_name                     0
# num_private                  0
# basin                        0
# subvillage                 371
# region                       0
# region_code                  0
# district_code                0
# lga                          0
# ward                         0
# population                   0
# public_meeting            3334
# recorded_by                  0
# scheme_management         3877
# scheme_name              28166
# permit                    3056
# construction_year            0
# extraction_type              0
# extraction_type_group        0
# extraction_type_class        0
# management                   0
# management_group             0
# payment                      0
# payment_type                 0
# water_quality                0
# quality_group                0
# quantity                     0
# quantity_group               0
# source                       0
# source_type                  0
# source_class                 0
# waterpoint_type              0
# waterpoint_type_group        0
# status_group                 0
# dtype: int64

# %% [markdown]
# #### Null Values

# %% [markdown]
# Dropping null values results in the loss of approx 10,000 entries

# %% [markdown]
# I will one-hot-encode 'null columns' for the features that contain these null values during preproccessing (Modeling Phase)

# %% [markdown]
# #### Dropping Columns

# %%
df.drop('scheme_name', axis=1, inplace=True)

# %%
df.drop('subvillage', axis=1, inplace=True)

# %%
df.drop('waterpoint_type_group', axis=1, inplace=True)

# %%
df.drop('quantity_group', axis=1, inplace=True)

# %%
df.drop('water_quality', axis=1, inplace=True)

# %%
df.drop('payment', axis=1, inplace=True)

# %% [markdown]
# 1. **Dropped Columns:**
#     - scheme_name (over half of values are null)
#     - subvillage (too many unique string values. Better geographical data exists)
#     - waterpoint_type_group (redundant)
#     - quantity_group (redundant)
#     - payment (redundant)
#     - water_quality (redundant)

# %% [markdown]
# #### Grouping Low-Frequency Values

# %%
df = df.replace({'funder': 'Ministry Of Water'}, 'Government Of Tanzania')

series = pd.value_counts(df['funder'])
mask = (series/series.sum() * 100).lt(1.75)
df['funder'] = np.where(df['funder'].isin(series[mask].index),'Other',df['funder'])

df = df.replace({'funder': '0'}, 'Other')

# %%
df['funder'].value_counts()
# Out:
# Other                     34462
# Government Of Tanzania     9674
# Danida                     3114
# Hesawa                     2202
# Rwssp                      1374
# World Bank                 1349
# Kkkt                       1287
# World Vision               1246
# Unicef                     1057
# Name: funder, dtype: int64

# %%
plt.figure(figsize=(10,10))
sns.countplot(y='funder', hue='status_group', data=df)
# Out:
# <AxesSubplot:xlabel='count', ylabel='funder'>

# %%
# groupby_test = df.groupby('funder').agg('count').reset_index()
# groupby_test.head()
# sns.barplot(x='status_group', y='funder', data=groupby_test[groupby_test['status_group'] > 1000])

# %% [markdown]
# I have strong reason to believe that 'Government of Tanzania' and 'Ministry of Water' can be lumped into one: https://en.wikipedia.org/wiki/Ministry_of_Water_and_Irrigation

# %%
#aggregating
df = df.replace({'installer': 'hesawa'}, 'HESAWA')
df = df.replace({'installer': 'Central government'}, 'Government')
df = df.replace({'installer': 'Commu'}, 'Community')

#cleaning 
df = df.replace({'installer': 'DANID'}, 'DANIDA' )

# %%
series = pd.value_counts(df['installer'])
mask = (series/series.sum() * 100).lt(1.75)
df['installer'] = np.where(df['installer'].isin(series[mask].index),'Other',df['installer'])
df['installer'].value_counts()

df = df.replace({'installer': '0'}, 'Other')

# %%
df['installer'].value_counts()
# Out:
# Other         31475
# DWE           17402
# Government     2447
# Community      1613
# DANIDA         1602
# RWE            1206
# Name: installer, dtype: int64

# %%
plt.figure(figsize=(10,10))
sns.countplot(y='installer', hue='status_group', data=df)
# Out:
# <AxesSubplot:xlabel='count', ylabel='installer'>

# %% [markdown]
# The following values have been aggregated due to the belief that they were entered with spelling errors

# %%
#aggregating
df = df.replace({'wpt_name': 'Shuleni'}, 'School')
df = df.replace({'wpt_name': 'Shule'}, 'School')
df = df.replace({'wpt_name': 'Shule Ya Misingi'}, 'School')

series = pd.value_counts(df['wpt_name'])
mask = (series/series.sum() * 100).lt(1.55)
df['wpt_name'] = np.where(df['wpt_name'].isin(series[mask].index),'Other',df['wpt_name'])

df = df.replace({'wpt_name': 'none'}, 'Other')

# %%
df['wpt_name'].value_counts()
# Out:
# Other     57292
# School     2108
# Name: wpt_name, dtype: int64

# %%
plt.figure(figsize=(10,10))
sns.countplot(y='wpt_name', hue='status_group', data=df)
# Out:
# <AxesSubplot:xlabel='count', ylabel='wpt_name'>

# %% [markdown]
# #### construction_year (missing values)

# %%
sorted(df['construction_year'].unique())
# Out:
# [0,
#  1960,
#  1961,
#  1962,
#  1963,
#  1964,
#  1965,
#  1966,
#  1967,
#  1968,
#  1969,
#  1970,
#  1971,
#  1972,
#  1973,
#  1974,
#  1975,
#  1976,
#  1977,
#  1978,
#  1979,
#  1980,
#  1981,
#  1982,
#  1983,
#  1984,
#  1985,
#  1986,
#  1987,
#  1988,
#  1989,
#  1990,
#  1991,
#  1992,
#  1993,
#  1994,
#  1995,
#  1996,
#  1997,
#  1998,
#  1999,
#  2000,
#  2001,
#  2002,
#  2003,
#  2004,
#  2005,
#  2006,
#  2007,
#  2008,
#  2009,
#  2010,
#  2011,
#  2012,
#  2013]

# %% [markdown]
# #### well_age

# %% [markdown]
# Before I bin the construction_year feature, I am going to make use of what information is given to calculate the age of each well

# %%
df['well_age'] = 2013 - df['construction_year']
df = df.replace({'well_age': 2013}, 100 )

# %% [markdown]
# #### binning construction_year

# %%
df[(df['construction_year'] < 1970)]['construction_year'].value_counts().sum() - 20709
# Out:
# 538

# %%
df[(df['construction_year'] < 1980) & (df['construction_year'] > 1969)]['construction_year'].value_counts().sum()
# Out:
# 4406

# %%
df[(df['construction_year'] < 1990) & (df['construction_year'] > 1979)]['construction_year'].value_counts().sum()
# Out:
# 5578

# %%
df[(df['construction_year'] < 2000) & (df['construction_year'] > 1989)]['construction_year'].value_counts().sum()
# Out:
# 7678

# %%
df[(df['construction_year'] < 2010) & (df['construction_year'] > 2000)]['construction_year'].value_counts().sum()
# Out:
# 13239

# %%
df[(df['construction_year'] >= 2010)]['construction_year'].value_counts().sum()
# Out:
# 5161

# %% [markdown]
# **OBSERVATION**
# 1. Nearly half of the entries are missing a construction year
# 2. Construction year goes back consistantly to 1960
#     - I will bin construction years and create a 'null' column during preprocessing
#     - BINS = 1960 - 1989, 1990-199, 2000-2009, 2010+

# %%
# bins=[-1,1959,1989,1999,2009,2014]

# df['year_constructed']= pd.cut(df['construction_year'],
#                               bins=bins,
#                               labels= ['Unknown','60s - 80s', '1990s', '2000s', '2010+'])

# df.drop('construction_year', axis=1, inplace=True)

# %% [markdown]
# #### Assessing Geographic Data

# %% [markdown]
# - subvillage
# - region
# - region_code
# - district_code
# - lga
# - ward

# %%
df['region'].value_counts()
# Out:
# Iringa           5294
# Shinyanga        4982
# Mbeya            4639
# Kilimanjaro      4379
# Morogoro         4006
# Arusha           3350
# Kagera           3316
# Mwanza           3102
# Kigoma           2816
# Ruvuma           2640
# Pwani            2635
# Tanga            2547
# Dodoma           2201
# Singida          2093
# Mara             1969
# Tabora           1959
# Rukwa            1808
# Mtwara           1730
# Manyara          1583
# Lindi            1546
# Dar es Salaam     805
# Name: region, dtype: int64

# %%
df['region_code'].value_counts()
# Out:
# 11    5300
# 17    5011
# 12    4639
# 3     4379
# 5     4040
# 18    3324
# 19    3047
# 2     3024
# 16    2816
# 10    2640
# 4     2513
# 1     2201
# 13    2093
# 14    1979
# 20    1969
# 15    1808
# 6     1609
# 21    1583
# 80    1238
# 60    1025
# 90     917
# 7      805
# 99     423
# 9      390
# 24     326
# 8      300
# 40       1
# Name: region_code, dtype: int64

# %%
len(df['region'].unique()) - len(df['region_code'].unique())
# Out:
# -6

# %%
df['district_code'].value_counts()
# Out:
# 1     12203
# 2     11173
# 3      9998
# 4      8999
# 5      4356
# 6      4074
# 7      3343
# 8      1043
# 30      995
# 33      874
# 53      745
# 43      505
# 13      391
# 23      293
# 63      195
# 62      109
# 60       63
# 0        23
# 80       12
# 67        6
# Name: district_code, dtype: int64

# %%
len(df['district_code'].unique()) - len(df['region'].unique())
# Out:
# -1

# %%
df['lga'].value_counts()
# Out:
# Njombe          2503
# Arusha Rural    1252
# Moshi Rural     1251
# Bariadi         1177
# Rungwe          1106
#                 ...
# Moshi Urban       79
# Kigoma Urban      71
# Arusha Urban      63
# Lindi Urban       21
# Nyamagana          1
# Name: lga, Length: 125, dtype: int64

# %%
df['ward'].value_counts()
# Out:
# Igosi               307
# Imalinyi            252
# Siha Kati           232
# Mdandu              231
# Nduruma             217
#                    ...
# Simbay                1
# Kinungu               1
# Kapilula              1
# Mwanga Kaskazini      1
# Ikweha                1
# Name: ward, Length: 2092, dtype: int64

# %% [markdown]
# Based upon value counts, it would appear that 'region' will be the cleanest geographical data to work with

# %% [markdown]
# #### Continuous Data

# %%
df.describe()
# Out:
#           amount_tsh    gps_height     longitude      latitude   num_private  \
# count   59400.000000  59400.000000  59400.000000  5.940000e+04  59400.000000
# mean      317.650385    668.297239     34.077427 -5.706033e+00      0.474141
# std      2997.574558    693.116350      6.567432  2.946019e+00     12.236230
# min         0.000000    -90.000000      0.000000 -1.164944e+01      0.000000
# 25%         0.000000      0.000000     33.090347 -8.540621e+00      0.000000
# 50%         0.000000    369.000000     34.908743 -5.021597e+00      0.000000
# 75%        20.000000   1319.250000     37.178387 -3.326156e+00      0.000000
# max    350000.000000   2770.000000     40.345193 -2.000000e-08   1776.000000
#
#         region_code  district_code    population  construction_year  \
# count  59400.000000   59400.000000  59400.000000       59400.000000
# mean      15.297003       5.629747    179.909983        1300.652475
# std       17.587406       9.633649    471.482176         951.620547
# min        1.000000       0.000000      0.000000           0.000000
# 25%        5.000000       2.000000      0.000000           0.000000
# 50%       12.000000       3.000000     25.000000        1986.000000
# 75%       17.000000       5.000000    215.000000        2004.000000
# max       99.000000      80.000000  30500.000000        2013.000000
#
#            well_age
# count  59400.000000
# mean      45.406162
# std       41.190108
# min        0.000000
# 25%        9.000000
# 50%       27.000000
# 75%      100.000000
# max      100.000000

# %% [markdown]
# #### Dealing with Population

# %%
df[(df['population'] == 0)]
# Out:
#        amount_tsh date_recorded                  funder  gps_height  \
# 4             0.0    2011-07-13                   Other           0
# 6             0.0    2012-10-01                   Other           0
# 7             0.0    2012-10-09                   Rwssp           0
# 8             0.0    2012-11-03                   Other           0
# 9             0.0    2011-08-03                   Other           0
# ...           ...           ...                     ...         ...
# 59384         0.0    2011-07-10                   Other           0
# 59392         0.0    2011-04-15  Government Of Tanzania           0
# 59393         0.0    2012-10-27                   Other           0
# 59397         0.0    2011-04-11                     NaN           0
# 59398         0.0    2011-03-08                   Other           0
#
#         installer  longitude  latitude wpt_name  num_private            basin  \
# 4           Other  31.130847 -1.825359   School            0    Lake Victoria
# 6           Other  33.362410 -3.766365    Other            0         Internal
# 7             DWE  32.620617 -4.226198    Other            0  Lake Tanganyika
# 8           Other  32.711100 -5.146712    Other            0  Lake Tanganyika
# 9           Other  30.626991 -1.257051    Other            0    Lake Victoria
# ...           ...        ...       ...      ...          ...              ...
# 59384       Other  30.667805 -2.483710    Other            0    Lake Victoria
# 59392  Government  33.009440 -8.520888    Other            0       Lake Rukwa
# 59393       Other  33.866852 -4.287410    Other            0         Internal
# 59397         NaN  34.017087 -8.750434    Other            0           Rufiji
# 59398       Other  35.861315 -6.378573    Other            0           Rufiji
#
#        ... management_group  payment_type  quality_group      quantity  \
# 4      ...            other     never pay           good      seasonal
# 6      ...       user-group     never pay           good        enough
# 7      ...       user-group       unknown          milky        enough
# 8      ...       user-group     never pay          salty      seasonal
# 9      ...       user-group     never pay           good        enough
# ...    ...              ...           ...            ...           ...
# 59384  ...       user-group     never pay           good  insufficient
# 59392  ...       user-group     never pay           good        enough
# 59393  ...       commercial    per bucket           good  insufficient
# 59397  ...       user-group       monthly       fluoride        enough
# 59398  ...       user-group     never pay           good  insufficient
#
#                      source           source_type source_class  \
# 4      rainwater harvesting  rainwater harvesting      surface
# 6               machine dbh              borehole  groundwater
# 7              shallow well          shallow well  groundwater
# 8               machine dbh              borehole  groundwater
# 9              shallow well          shallow well  groundwater
# ...                     ...                   ...          ...
# 59384                spring                spring  groundwater
# 59392                spring                spring  groundwater
# 59393                   dam                   dam      surface
# 59397           machine dbh              borehole  groundwater
# 59398          shallow well          shallow well  groundwater
#
#           waterpoint_type    status_group well_age
# 4      communal standpipe      functional      100
# 6               hand pump  non functional      100
# 7               hand pump  non functional      100
# 8               hand pump  non functional      100
# 9               hand pump      functional      100
# ...                   ...             ...      ...
# 59384  communal standpipe  non functional      100
# 59392  communal standpipe  non functional      100
# 59393               other      functional      100
# 59397           hand pump      functional      100
# 59398           hand pump      functional      100
#
# [21381 rows x 35 columns]

# %%
df['population'].value_counts()
# Out:
# 0       21381
# 1        7025
# 200      1940
# 150      1892
# 250      1681
#         ...
# 3241        1
# 1960        1
# 1685        1
# 2248        1
# 1439        1
# Name: population, Length: 1049, dtype: int64

# %% [markdown]
# Nearly half the data for 'population' is 0 and 1

# %% [markdown]
# My best option is to bin

# %%
#df[(df['population'] < 100) & (df['population'] > 1)]

# %%
#df[(df['population'] < 500) & (df['population'] > 1)]

# %%
#df[(df['population'] < 200) & (df['population'] > 1)]

# %%
#df[(df['population'] > 200) ]

# %%
# bins = [-1,1,199,30501]
# df['population_grouped'] = pd.cut(df['population'],
#                                  bins=bins,
#                                  labels=['Unknown', '<200', '>200'])

# %% [markdown]
# #### gps_height (Altitude)

# %%
df['altitude'] = df['gps_height']
df.drop('gps_height', axis=1, inplace=True)

# %%
sns.histplot(df['altitude'])
# Out:
# <AxesSubplot:xlabel='altitude', ylabel='Count'>

# %% [markdown]
# **OBSERVATION**
# 1. While 0 is an acceptable value for altitude, I do not believe that there are this many wells at an altitude of 0

# %% [markdown]
# #### Month Recorded

# %% [markdown]
# Tanzania experiences its wetest season in March/April, and its driest during June/July/August

# %% [markdown]
# The month the status of the well was recorded could be revealing

# %%
df['month_recorded']=pd.to_datetime(df['date_recorded']).dt.month
df['year_recorded']=pd.to_datetime(df['date_recorded']).dt.year

# %%
df.drop('date_recorded', axis=1, inplace=True)

# %%
df = df[(df['year_recorded']) > 2005]

# %% [markdown]
# ## Revisitin Null Values

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 59369 entries, 0 to 59399
# Data columns (total 36 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   amount_tsh             59369 non-null  float64
#  1   funder                 55736 non-null  object
#  2   installer              55716 non-null  object
#  3   longitude              59369 non-null  float64
#  4   latitude               59369 non-null  float64
#  5   wpt_name               59369 non-null  object
#  6   num_private            59369 non-null  int64
#  7   basin                  59369 non-null  object
#  8   region                 59369 non-null  object
#  9   region_code            59369 non-null  int64
#  10  district_code          59369 non-null  int64
#  11  lga                    59369 non-null  object
#  12  ward                   59369 non-null  object
#  13  population             59369 non-null  int64
#  14  public_meeting         56041 non-null  object
#  15  recorded_by            59369 non-null  object
#  16  scheme_management      55496 non-null  object
#  17  permit                 56314 non-null  object
#  18  construction_year      59369 non-null  int64
#  19  extraction_type        59369 non-null  object
#  20  extraction_type_group  59369 non-null  object
#  21  extraction_type_class  59369 non-null  object
#  22  management             59369 non-null  object
#  23  management_group       59369 non-null  object
#  24  payment_type           59369 non-null  object
#  25  quality_group          59369 non-null  object
#  26  quantity               59369 non-null  object
#  27  source                 59369 non-null  object
#  28  source_type            59369 non-null  object
#  29  source_class           59369 non-null  object
#  30  waterpoint_type        59369 non-null  object
#  31  status_group           59369 non-null  object
#  32  well_age               59369 non-null  int64
#  33  altitude               59369 non-null  int64
#  34  month_recorded         59369 non-null  int64
#  35  year_recorded          59369 non-null  int64
# dtypes: float64(3), int64(9), object(24)
# memory usage: 16.8+ MB

# %%
df.dropna(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 48630 entries, 0 to 59399
# Data columns (total 36 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   amount_tsh             48630 non-null  float64
#  1   funder                 48630 non-null  object
#  2   installer              48630 non-null  object
#  3   longitude              48630 non-null  float64
#  4   latitude               48630 non-null  float64
#  5   wpt_name               48630 non-null  object
#  6   num_private            48630 non-null  int64
#  7   basin                  48630 non-null  object
#  8   region                 48630 non-null  object
#  9   region_code            48630 non-null  int64
#  10  district_code          48630 non-null  int64
#  11  lga                    48630 non-null  object
#  12  ward                   48630 non-null  object
#  13  population             48630 non-null  int64
#  14  public_meeting         48630 non-null  object
#  15  recorded_by            48630 non-null  object
#  16  scheme_management      48630 non-null  object
#  17  permit                 48630 non-null  object
#  18  construction_year      48630 non-null  int64
#  19  extraction_type        48630 non-null  object
#  20  extraction_type_group  48630 non-null  object
#  21  extraction_type_class  48630 non-null  object
#  22  management             48630 non-null  object
#  23  management_group       48630 non-null  object
#  24  payment_type           48630 non-null  object
#  25  quality_group          48630 non-null  object
#  26  quantity               48630 non-null  object
#  27  source                 48630 non-null  object
#  28  source_type            48630 non-null  object
#  29  source_class           48630 non-null  object
#  30  waterpoint_type        48630 non-null  object
#  31  status_group           48630 non-null  object
#  32  well_age               48630 non-null  int64
#  33  altitude               48630 non-null  int64
#  34  month_recorded         48630 non-null  int64
#  35  year_recorded          48630 non-null  int64
# dtypes: float64(3), int64(9), object(24)
# memory usage: 13.7+ MB

# %%
df['source_type'].value_counts()
# Out:
# spring                  14979
# shallow well            12409
# borehole                 9733
# river/lake               9109
# rainwater harvesting     1605
# dam                       581
# other                     214
# Name: source_type, dtype: int64

# %%
df['source_class'].value_counts()
# Out:
# groundwater    37121
# surface        11295
# unknown          214
# Name: source_class, dtype: int64

# %%
df['source'].value_counts()
# Out:
# spring                  14979
# shallow well            12409
# machine dbh              8955
# river                    8504
# rainwater harvesting     1605
# hand dtw                  778
# lake                      605
# dam                       581
# other                     182
# unknown                    32
# Name: source, dtype: int64

# %%
df.drop('source_type', axis=1, inplace=True)

# %%
df['payment_type'].value_counts()
# Out:
# never pay     20771
# per bucket     8112
# monthly        7542
# unknown        4169
# on failure     3640
# annually       3468
# other           928
# Name: payment_type, dtype: int64

# %%
df['management_group'].value_counts()
# Out:
# user-group    43633
# commercial     3045
# parastatal     1330
# other           548
# unknown          74
# Name: management_group, dtype: int64

# %%
df['extraction_type'].value_counts()
# Out:
# gravity                      23159
# nira/tanira                   6259
# other                         4537
# submersible                   3753
# swn 80                        2857
# mono                          2499
# india mark ii                 2045
# afridev                       1346
# ksb                           1330
# other - rope pump              212
# other - swn 81                 199
# windmill                       104
# cemo                            89
# india mark iii                  86
# other - play pump               76
# walimi                          46
# climax                          32
# other - mkulima/shinyanga        1
# Name: extraction_type, dtype: int64

# %%
df['extraction_type_group'].value_counts()
# Out:
# gravity            23159
# nira/tanira         6259
# submersible         5083
# other               4537
# swn 80              2857
# mono                2499
# india mark ii       2045
# afridev             1346
# other handpump       322
# rope pump            212
# other motorpump      121
# wind-powered         104
# india mark iii        86
# Name: extraction_type_group, dtype: int64

# %%
df.drop('extraction_type', axis=1, inplace=True)

# %%
df['extraction_type_class'].value_counts()
# Out:
# gravity         23159
# handpump        12915
# submersible      5083
# other            4537
# motorpump        2620
# rope pump         212
# wind-powered      104
# Name: extraction_type_class, dtype: int64

# %%
df['scheme_management'].value_counts()
# Out:
# VWC                 32681
# WUG                  4237
# Water authority      2919
# WUA                  2634
# Water Board          2489
# Parastatal           1293
# Company              1028
# Private operator      804
# Other                 376
# SWC                    97
# Trust                  71
# None                    1
# Name: scheme_management, dtype: int64

# %%
df['recorded_by'].value_counts()
# Out:
# GeoData Consultants Ltd    48630
# Name: recorded_by, dtype: int64

# %%
df.drop('recorded_by', axis=1, inplace=True)

# %%
len(df['ward'].unique())
# Out:
# 1875

# %%
df.drop('ward', axis=1, inplace=True)

# %%
df['lga'].value_counts()
# Out:
# Njombe           2454
# Moshi Rural      1226
# Arusha Rural     1173
# Kilosa           1057
# Kasulu           1039
#                  ...
# Tarime             39
# Ilala              36
# Ileje              27
# Singida Rural      17
# Nyamagana           1
# Name: lga, Length: 118, dtype: int64

# %%
df.drop('lga', axis=1, inplace=True)

# %% [markdown]
# # EDA

# %%
df.describe()
# Out:
#           amount_tsh     longitude      latitude   num_private   region_code  \
# count   48630.000000  48630.000000  4.863000e+04  48630.000000  48630.000000
# mean      357.870952     34.230648 -5.703317e+00      0.548262     14.684598
# std      2818.635008      6.309842  2.860211e+00     13.244462     17.199136
# min         0.000000      0.000000 -1.164944e+01      0.000000      1.000000
# 25%         0.000000     33.050844 -8.219467e+00      0.000000      5.000000
# 50%         0.000000     35.265112 -5.017793e+00      0.000000     12.000000
# 75%        50.000000     37.338478 -3.337886e+00      0.000000     17.000000
# max    250000.000000     40.323402 -2.000000e-08   1776.000000     99.000000
#
#        district_code    population  construction_year      well_age  \
# count   48630.000000  48630.000000       48630.000000  48630.000000
# mean        5.730393    175.389595        1332.920193     44.104668
# std         9.665276    471.061012         940.708415     40.767786
# min         0.000000      0.000000           0.000000      0.000000
# 25%         2.000000      0.000000           0.000000      8.000000
# 50%         3.000000     30.000000        1986.000000     27.000000
# 75%         5.000000    200.000000        2005.000000    100.000000
# max        80.000000  30500.000000        2013.000000    100.000000
#
#            altitude  month_recorded  year_recorded
# count  48630.000000    48630.000000   48630.000000
# mean     696.445157        4.318857    2011.899712
# std      698.813656        2.992206       0.944249
# min      -90.000000        1.000000    2011.000000
# 25%        0.000000        2.000000    2011.000000
# 50%      452.000000        3.000000    2011.000000
# 75%     1332.000000        7.000000    2013.000000
# max     2770.000000       12.000000    2013.000000

# %%
fig, ax = plt.subplots(figsize=(10,5))


imbalance_plot= sns.countplot(ax=ax,
              x='status_group', 
              data=df,
             color = 'orange')

plt.xticks([0,1,2], 
           ['Functional', 'Non-Functional', 'Functional-Needs Repair'],
          fontsize=12)
plt.yticks(fontsize=12)
plt.xlabel(xlabel='Status', fontsize=14)
plt.ylabel(ylabel='Count', fontsize=14);
# Out:
# ''

# %% [markdown]
# **OBSERVATION**
# 1. There are far more functional wells than non-functional / needs repair
# 2. I will need to address the class imbalances during preprocessing / modeling

# %%
sns.scatterplot(x='status_group', y='amount_tsh', data=df)
# Out:
# <AxesSubplot:xlabel='status_group', ylabel='amount_tsh'>

# %%
tsh_df = df

# %%
tsh_df = tsh_df[(tsh_df['amount_tsh'] < 150000)]

# %%
sns.scatterplot(x='status_group', y='amount_tsh', data=tsh_df)
# Out:
# <AxesSubplot:xlabel='status_group', ylabel='amount_tsh'>

# %% [markdown]
# **OBSERVATION**
# 1. It would appear that higher amounts of static head correlates with being functional; however it is very likely that this is due to the class imbalance

# %%
plt.figure(figsize=(10,10))
sns.countplot(y='funder', hue='status_group', data=df)
# Out:
# <AxesSubplot:xlabel='count', ylabel='funder'>

# %%
df.drop('funder', axis=1, inplace=True)

# %%
plt.figure(figsize=(10,10))
sns.countplot(y='installer', hue='status_group', data=df)
# Out:
# <AxesSubplot:xlabel='count', ylabel='installer'>

# %%
df.drop('installer', axis=1, inplace=True)

# %%
plt.figure(figsize=(10,10))
sns.countplot(y='management_group', hue='status_group', data=df)
# Out:
# <AxesSubplot:xlabel='count', ylabel='management_group'>

# %%
plt.figure(figsize=(10,10))
sns.countplot(y='management', hue='status_group', data=df)
# Out:
# <AxesSubplot:xlabel='count', ylabel='management'>

# %%
df.drop('management',axis=1, inplace=True)

# %%
sns.scatterplot(x='status_group', y='population', data=df)
# Out:
# <AxesSubplot:xlabel='status_group', ylabel='population'>

# %%
df.groupby('status_group').population.median()
# Out:
# status_group
# functional                 40
# functional needs repair    50
# non functional              1
# Name: population, dtype: int64

# %% [markdown]
# **OBSERVATION**
# 1. small populations may correlate with non-functional wells, as it may be more imperative that resources are spent on more populous wells
# 2. functional wells may have a slightly smaller associated population due to less frequent use

# %%
sns.scatterplot(x='status_group', y='altitude', data=df)
# Out:
# <AxesSubplot:xlabel='status_group', ylabel='altitude'>

# %%
age_df = df[(df['well_age'] < 100)]

# %%
sns.scatterplot(x='status_group', y='well_age', data=age_df)
# Out:
# <AxesSubplot:xlabel='status_group', ylabel='well_age'>

# %%
plt.figure(figsize=(10,10))
sns.countplot(y='well_age', hue='status_group', data=df)
# Out:
# <AxesSubplot:xlabel='count', ylabel='well_age'>

# %% [markdown]
# **OBSERVATION**
# 1. there are typically more non-functional wells than functional wells for wells 28 years and over

# %%
df[(df['population'] > 20000)]['region']
# Out:
# 30537    Tanga
# Name: region, dtype: object

# %% [markdown]
# Tanga is a large port city in the NorthEast of Tanzania, this datapoint could make sense
# https://en.wikipedia.org/wiki/Tanga,_Tanzania

# %%
plt.figure(figsize=(10,10))
sns.countplot(y='month_recorded', hue='status_group', data=df)
# Out:
# <AxesSubplot:xlabel='count', ylabel='month_recorded'>

# %% [markdown]
# **OBSERVATION**
# 1. most of the data collected is collected in the first quarter of the year (Jan - March)
# 2. May, July, September, and December seem to have very little recordings
# 3. June - October are the driest seasons: it would appear that there is a spike in recordings halfway through the dry season

# %%
plt.figure(figsize=(10,10))
sns.countplot(y='year_recorded', hue='status_group', data=df)
# Out:
# <AxesSubplot:xlabel='count', ylabel='year_recorded'>

# %%
df.drop('year_recorded', axis=1, inplace=True)

# %%
plt.figure(figsize=(10,10))
sns.countplot(y='quality_group', hue='status_group', data=df)
# Out:
# <AxesSubplot:xlabel='count', ylabel='quality_group'>

# %%
quality_df = df[(df['quality_group'] != 'good')]

# %%
plt.figure(figsize=(10,10))
sns.countplot(y='quality_group', hue='status_group', data=quality_df)
# Out:
# <AxesSubplot:xlabel='count', ylabel='quality_group'>

# %%
plt.figure(figsize=(10,10))
sns.countplot(y='quantity', hue='status_group', data=df)
# Out:
# <AxesSubplot:xlabel='count', ylabel='quantity'>

# %%
plt.figure(figsize=(10,10))
sns.countplot(y='basin', hue='status_group', data=df)
# Out:
# <AxesSubplot:xlabel='count', ylabel='basin'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 48630 entries, 0 to 59399
# Data columns (total 27 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   amount_tsh             48630 non-null  float64
#  1   longitude              48630 non-null  float64
#  2   latitude               48630 non-null  float64
#  3   wpt_name               48630 non-null  object
#  4   num_private            48630 non-null  int64
#  5   basin                  48630 non-null  object
#  6   region                 48630 non-null  object
#  7   region_code            48630 non-null  int64
#  8   district_code          48630 non-null  int64
#  9   population             48630 non-null  int64
#  10  public_meeting         48630 non-null  object
#  11  scheme_management      48630 non-null  object
#  12  permit                 48630 non-null  object
#  13  construction_year      48630 non-null  int64
#  14  extraction_type_group  48630 non-null  object
#  15  extraction_type_class  48630 non-null  object
#  16  management_group       48630 non-null  object
#  17  payment_type           48630 non-null  object
#  18  quality_group          48630 non-null  object
#  19  quantity               48630 non-null  object
#  20  source                 48630 non-null  object
#  21  source_class           48630 non-null  object
#  22  waterpoint_type        48630 non-null  object
#  23  status_group           48630 non-null  object
#  24  well_age               48630 non-null  int64
#  25  altitude               48630 non-null  int64
#  26  month_recorded         48630 non-null  int64
# dtypes: float64(3), int64(8), object(16)
# memory usage: 11.6+ MB

# %%
plt.figure(figsize=(10,10))
sns.countplot(y='scheme_management', hue='status_group', data=df)
# Out:
# <AxesSubplot:xlabel='count', ylabel='scheme_management'>

# %%
plt.figure(figsize=(20,15))
sns.scatterplot(x='longitude', y='latitude', hue='status_group', data=df)
# Out:
# <AxesSubplot:xlabel='longitude', ylabel='latitude'>

# %%
df.describe()
# Out:
#           amount_tsh     longitude      latitude   num_private   region_code  \
# count   48630.000000  48630.000000  4.863000e+04  48630.000000  48630.000000
# mean      357.870952     34.230648 -5.703317e+00      0.548262     14.684598
# std      2818.635008      6.309842  2.860211e+00     13.244462     17.199136
# min         0.000000      0.000000 -1.164944e+01      0.000000      1.000000
# 25%         0.000000     33.050844 -8.219467e+00      0.000000      5.000000
# 50%         0.000000     35.265112 -5.017793e+00      0.000000     12.000000
# 75%        50.000000     37.338478 -3.337886e+00      0.000000     17.000000
# max    250000.000000     40.323402 -2.000000e-08   1776.000000     99.000000
#
#        district_code    population  construction_year      well_age  \
# count   48630.000000  48630.000000       48630.000000  48630.000000
# mean        5.730393    175.389595        1332.920193     44.104668
# std         9.665276    471.061012         940.708415     40.767786
# min         0.000000      0.000000           0.000000      0.000000
# 25%         2.000000      0.000000           0.000000      8.000000
# 50%         3.000000     30.000000        1986.000000     27.000000
# 75%         5.000000    200.000000        2005.000000    100.000000
# max        80.000000  30500.000000        2013.000000    100.000000
#
#            altitude  month_recorded
# count  48630.000000    48630.000000
# mean     696.445157        4.318857
# std      698.813656        2.992206
# min      -90.000000        1.000000
# 25%        0.000000        2.000000
# 50%      452.000000        3.000000
# 75%     1332.000000        7.000000
# max     2770.000000       12.000000

# %%
df[df['longitude'] == 0]
# Out:
#        amount_tsh  longitude      latitude wpt_name  num_private  \
# 53            0.0        0.0 -2.000000e-08    Other            0
# 168           0.0        0.0 -2.000000e-08    Other            0
# 256           0.0        0.0 -2.000000e-08    Other            0
# 301           0.0        0.0 -2.000000e-08    Other            0
# 306           0.0        0.0 -2.000000e-08    Other            0
# ...           ...        ...           ...      ...          ...
# 59135         0.0        0.0 -2.000000e-08    Other            0
# 59158         0.0        0.0 -2.000000e-08    Other            0
# 59189         0.0        0.0 -2.000000e-08    Other            0
# 59295         0.0        0.0 -2.000000e-08    Other            0
# 59374         0.0        0.0 -2.000000e-08    Other            0
#
#                basin     region  region_code  district_code  population  ...  \
# 53     Lake Victoria     Mwanza           19              6           0  ...
# 168    Lake Victoria  Shinyanga           17              1           0  ...
# 256    Lake Victoria     Mwanza           19              6           0  ...
# 301    Lake Victoria     Mwanza           19              6           0  ...
# 306    Lake Victoria     Mwanza           19              6           0  ...
# ...              ...        ...          ...            ...         ...  ...
# 59135  Lake Victoria     Mwanza           19              6           0  ...
# 59158  Lake Victoria  Shinyanga           17              1           0  ...
# 59189  Lake Victoria  Shinyanga           17              1           0  ...
# 59295  Lake Victoria  Shinyanga           17              1           0  ...
# 59374  Lake Victoria  Shinyanga           17              1           0  ...
#
#       payment_type quality_group      quantity                source  \
# 53         unknown       unknown           dry           machine dbh
# 168          other          good      seasonal  rainwater harvesting
# 256      never pay       unknown           dry           machine dbh
# 301      never pay          good  insufficient           machine dbh
# 306      never pay          good  insufficient           machine dbh
# ...            ...           ...           ...                   ...
# 59135    never pay          good        enough          shallow well
# 59158    never pay          good        enough          shallow well
# 59189        other          good        enough          shallow well
# 59295    never pay          good        enough          shallow well
# 59374        other          good        enough          shallow well
#
#       source_class              waterpoint_type             status_group  \
# 53     groundwater  communal standpipe multiple           non functional
# 168        surface           communal standpipe               functional
# 256    groundwater                    hand pump           non functional
# 301    groundwater                    hand pump               functional
# 306    groundwater                    hand pump               functional
# ...            ...                          ...                      ...
# 59135  groundwater                    hand pump               functional
# 59158  groundwater                    hand pump               functional
# 59189  groundwater                    hand pump  functional needs repair
# 59295  groundwater                    hand pump  functional needs repair
# 59374  groundwater                    hand pump               functional
#
#       well_age altitude month_recorded
# 53         100        0              8
# 168        100        0              1
# 256        100        0              7
# 301        100        0              7
# 306        100        0              7
# ...        ...      ...            ...
# 59135      100        0              8
# 59158      100        0              7
# 59189      100        0              7
# 59295      100        0              7
# 59374      100        0             10
#
# [1326 rows x 27 columns]

# %%
df = df[df['longitude'] > 0]

# %%
map_df = df

# %%
map_df = map_df[(map_df['longitude'] > 0)]

# %%
map_df[(map_df['longitude'] == 0)]
# Out:
# Empty DataFrame
# Columns: [amount_tsh, longitude, latitude, wpt_name, num_private, basin, region, region_code, district_code, population, public_meeting, scheme_management, permit, construction_year, extraction_type_group, extraction_type_class, management_group, payment_type, quality_group, quantity, source, source_class, waterpoint_type, status_group, well_age, altitude, month_recorded]
# Index: []
#
# [0 rows x 27 columns]

# %%
plt.figure(figsize=(20,15))
sns.scatterplot(x='longitude', y='latitude', hue='status_group', data=map_df)
# Out:
# <AxesSubplot:xlabel='longitude', ylabel='latitude'>

# %%
plt.figure(figsize=(20,15))
sns.scatterplot(x='longitude', y='latitude', hue='population_grouped', data=map_df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-109-1efe3f97d601> in <module>
#       1 plt.figure(figsize=(20,15))
# ----> 2 sns.scatterplot(x='longitude', y='latitude', hue='population_grouped', data=map_df)
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/seaborn/relational.py in scatterplot(x, y, hue, style, size, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, x_bins, y_bins, units, estimator, ci, n_boot, alpha, x_jitter, y_jitter, legend, ax, **kwargs)
#     792
#     793     variables = _ScatterPlotter.get_semantics(locals())
# --> 794     p = _ScatterPlotter(
#     795         data=data, variables=variables,
#     796         x_bins=x_bins, y_bins=y_bins,
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/seaborn/relational.py in __init__(self, data, variables, x_bins, y_bins, estimator, ci, n_boot, alpha, x_jitter, y_jitter, legend)
#     578         )
#     579
# --> 580         super().__init__(data=data, variables=variables)
#     581
#     582         self.alpha = alpha
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/seaborn/_core.py in __init__(self, data, variables)
#     602     def __init__(self, data=None, variables={}):
#     603
# --> 604         self.assign_variables(data, variables)
#     605
#     606         for var, cls in self._semantic_mappings.items():
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/seaborn/_core.py in assign_variables(self, data, variables)
#     665         else:
#     666             self.input_format = "long"
# --> 667             plot_data, variables = self._assign_variables_longform(
#     668                 data, **variables,
#     669             )
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/seaborn/_core.py in _assign_variables_longform(self, data, **kwargs)
#     885                     # We don't know what this name means
#     886                     err = f"Could not interpret value `{val}` for parameter `{key}`"
# --> 887                     raise ValueError(err)
#     888
#     889             else:
#
# ValueError: Could not interpret value `population_grouped` for parameter `hue`

# %%
plt.figure(figsize=(20,15))
sns.scatterplot(x='longitude', y='latitude', hue='region', data=map_df)

# %%
plt.figure(figsize=(20,15))
sns.scatterplot(x='longitude', y='latitude', hue='basin', data=map_df)

# %%
df

# %% [markdown]
# # Modeling

# %%
df = df.replace({'status_group': 'functional'}, 1)
df = df.replace({'status_group': 'non functional'}, 2)
df = df.replace({'status_group': 'functional needs repair'}, 3)

# %% [markdown]
# ### Logistic Regression - Baseline

# %%
#splitting features and target
#creating dummy variables for categorical data
X = df.drop('status_group', axis=1)
X = pd.get_dummies(X, drop_first=True )

y = df['status_group']

# %%
#creating training and testing data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size= .25, random_state=2)

# %%
#scaling 
scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# ## Decision Tree Baseline

# %%
dt_base = DecisionTreeClassifier()

dt_base_model = dt_base.fit(X_train_scaled, y_train)

# %%
# fig, axes = plt.subplots(nrows = 1,ncols = 1, figsize = (3,3), dpi=300)
# tree.plot_tree(dt_base,
#                feature_names = X.columns, 
#                class_names=np.unique(y).astype('str'),
#                filled = True)
# plt.show()

# %%
print(classification_report(y_train, dt_base.predict(X_train_scaled)))
# Out:
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00     19656
#            2       1.00      1.00      1.00     13455
#            3       1.00      1.00      1.00      2367
#
#     accuracy                           1.00     35478
#    macro avg       1.00      1.00      1.00     35478
# weighted avg       1.00      1.00      1.00     35478

# %%
print(classification_report(y_test, dt_base.predict(X_test_scaled)))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.75      0.70      0.72      6471
#            2       0.66      0.71      0.68      4562
#            3       0.22      0.25      0.23       793
#
#     accuracy                           0.67     11826
#    macro avg       0.54      0.55      0.55     11826
# weighted avg       0.68      0.67      0.67     11826

# %%
print(dt_base.tree_.max_depth)
# Out:
# 44

# %% [markdown]
# **INTERPRETATION**
# 1. Extremely Overfit. The model knows the training data completely

# %%
fig, axes = plt.subplots(nrows = 1,ncols = 1, figsize = (20,15), dpi=300)
tree.plot_tree(dt_base,
               feature_names = X.columns, 
               class_names=np.unique(y).astype('str'),
               filled = True)
plt.show()

# %% [markdown]
# **OBSERVATION**
# 1. The long tails indicate the overfitting

# %%
plot_confusion_matrix(dt_base, X_test_scaled, y_test,
                     cmap=plt.cm.Blues)
plt.show()

# %% [markdown]
# **INTERPRETATION**
# 1. 2/3 is worst case scenario (predicted non functional, but is actually in need of repair)
# 2. 3/1 is pretty bad (predicted in need of repair, but is actually working)

# %% [markdown]
# ## Decision Tree - Gridsearch

# %%
dt_v2 = DecisionTreeClassifier()

weight_dict = {1: 1, 2: 1.5, 3: 8}
weight_dict2 = {1: 0.5, 2: 3, 3: 10}
weight_dict3 = {1: 0.25, 2: 6, 3: 12}

param_grid = {
    'criterion' : ['gini', 'entropy'],
    'class_weight': [weight_dict, weight_dict2, weight_dict3, 'balanced'],
    'max_depth' : [10, 20, 30],
    'min_samples_split' : [1.0, 3, 5],
    'min_samples_leaf' : [10, 15, 30]
}

dt_v2_model = GridSearchCV(estimator = dt_v2, param_grid=param_grid, cv=3)
dt_v2_model.fit(X_train_scaled, y_train)

# %%
print(dt_v2_model.best_params_)

# %%
print(classification_report(y_train, dt_v2_model.predict(X_train_scaled)))

# %%
plot_confusion_matrix(dt_v2_model, X_test_scaled, y_test,
                     cmap=plt.cm.Blues)
plt.show()

# %%
print(classification_report(y_test, dt_v2_model.predict(X_test_scaled)))

# %%
dt_v3 = DecisionTreeClassifier(criterion= 'entropy')

weight_dict = {1: 1, 2: 1.5, 3: 8}
weight_dict2 = {1: 0.5, 2: 1.5, 3: 8}

param_grid = {
    'class_weight': [weight_dict, weight_dict2],
    'max_depth' : [25, 30, 35],
    'min_samples_split' : [3, 5],
    'min_samples_leaf' : [9, 10, 11]
}

dt_v3_model = GridSearchCV(estimator = dt_v3, param_grid=param_grid, cv=3)
dt_v3_model.fit(X_train_scaled, y_train)

# %%
print(dt_v3_model.best_params_)

# %%
plot_confusion_matrix(dt_v3_model, X_test_scaled, y_test,
                     cmap=plt.cm.Blues)
plt.show()

# %%
print(classification_report(y_test, dt_v3_model.predict(X_test_scaled)))

# %%
dt_v4 = DecisionTreeClassifier(criterion= 'entropy', max_depth=30)

weight_dict = {1: 1, 2: 1.5, 3: 8}
weight_dict2 = {1: 1, 2: 3, 3: 10}

param_grid = {
    'class_weight': [weight_dict, weight_dict2],
    'min_samples_split' : [2, 3],
    'min_samples_leaf' : [7, 8, 9]
}

dt_v4_model = GridSearchCV(estimator = dt_v4, param_grid=param_grid, cv=3)
dt_v4_model.fit(X_train_scaled, y_train)

# %%
print(dt_v4_model.best_params_)

# %%
print(classification_report(y_test, dt_v4_model.predict(X_test_scaled)))

# %% [markdown]
# ### Decision Tree - SMOTE

# %% [markdown]
# Thus far I have onl been dealing with class imbalance by adjusting 'class_weight' in gridsearch. While this is a valid technique, I am seeing little improvement. Using SMOTE to create new synthetic data, rather than simply giving more weight to the minority classes (2 and 3), might yield useful insight.

# %%
#creating training and testing data
# X_train_sm, X_test_sm, y_train_sm, y_test_sm = train_test_split(X_sm, y_sm, test_size= .25, random_state=2)

# %%
sm = SMOTE(random_state=2)

X_train_sm, y_train_sm = sm.fit_resample(X_train, y_train)

# %%
#scaling 
scaler = StandardScaler()

X_train_scaled_sm = scaler.fit_transform(X_train_sm)
X_test_scaled = scaler.transform(X_test)

# %%
dt_smote_base = DecisionTreeClassifier()
dt_smote_base_model = dt_smote_base.fit(X_train_scaled_sm, y_train_sm)

# %%
print(classification_report(y_train_sm, dt_smote_base_model.predict(X_train_scaled_sm)))
# Out:
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00     19656
#            2       1.00      1.00      1.00     19656
#            3       1.00      1.00      1.00     19656
#
#     accuracy                           1.00     58968
#    macro avg       1.00      1.00      1.00     58968
# weighted avg       1.00      1.00      1.00     58968

# %%
print(classification_report(y_test, dt_smote_model.predict(X_test_scaled)))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.81      0.78      0.80      6471
#            2       0.77      0.75      0.76      4562
#            3       0.30      0.41      0.35       793
#
#     accuracy                           0.75     11826
#    macro avg       0.63      0.65      0.63     11826
# weighted avg       0.76      0.75      0.75     11826

# %%
print(dt_smote_model.tree_.max_depth)
# Out:
# 30

# %% [markdown]
# ### Decision Tree - Smote(2)

# %%
dt_smote_v2 = DecisionTreeClassifier()


param_grid = {
    'criterion' : ['gini', 'entropy'],
    'max_depth' : [10, 20, 25],
    'min_samples_split' : [1.0, 10, 20, 30],
    'min_samples_leaf' : [5, 10, 15]
}

dt_smote_v2_model = GridSearchCV(estimator = dt_smote_v2, param_grid=param_grid, cv=3)
dt_smote_v2_model.fit(X_train_scaled_sm, y_train_sm)

# %%
print(dt_smote_v2_model.best_params_)

# %%
print(classification_report(y_train_sm, dt_smote_v2_model.predict(X_train_scaled_sm)))

# %%
print(classification_report(y_test, dt_smote_v2_model.predict(X_test_scaled)))

# %% [markdown]
# ### Decision Tree - SMOTE (3)

# %%
dt_smote_v4 = DecisionTreeClassifier(max_depth=25, min_samples_leaf=5, min_samples_split=10)

# %%
dt_smote_v4.fit(X_train_scaled_sm, y_train_sm)
# Out:
# DecisionTreeClassifier(max_depth=25, min_samples_leaf=5, min_samples_split=10)

# %%
print(classification_report(y_train_sm, dt_smote_v4.predict(X_train_scaled_sm)))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.87      0.91      0.89     19656
#            2       0.90      0.87      0.89     19656
#            3       0.92      0.92      0.92     19656
#
#     accuracy                           0.90     58968
#    macro avg       0.90      0.90      0.90     58968
# weighted avg       0.90      0.90      0.90     58968

# %%
print(classification_report(y_test, dt_smote_v4.predict(X_test_scaled)))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.80      0.81      0.81      6471
#            2       0.78      0.73      0.76      4562
#            3       0.32      0.41      0.36       793
#
#     accuracy                           0.75     11826
#    macro avg       0.63      0.65      0.64     11826
# weighted avg       0.76      0.75      0.76     11826

# %% [markdown]
# **INTERPRETATION**
# 1. 3 is still extremely overfit, but other classes are performing okay (still some overfitting)
# 2. Looking at overall performance across all classes, this is my best Decision Tree
# 3. Even after using SMOTE, my model is still bad at predicting 3 (the minority class).
#     - experimenting with class weights provided no significant breakthroughs
#     - Knowing this, there may be specific features that make predicting the minority class very difficult, so RandomForest may be able to address this

# %% [markdown]
# ## Random Forest - Baseline

# %%
forest_base = RandomForestClassifier()
forest_base_model = forest_base.fit(X_train_scaled, y_train)

# %%
print(classification_report(y_train, forest_base_model.predict(X_train_scaled)))
# Out:
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00     19656
#            2       1.00      1.00      1.00     13455
#            3       1.00      1.00      1.00      2367
#
#     accuracy                           1.00     35478
#    macro avg       1.00      1.00      1.00     35478
# weighted avg       1.00      1.00      1.00     35478

# %%
print(classification_report(y_test, forest_base_model.predict(X_test_scaled)))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.78      0.88      0.83      6471
#            2       0.79      0.74      0.76      4562
#            3       0.47      0.19      0.28       793
#
#     accuracy                           0.78     11826
#    macro avg       0.68      0.60      0.62     11826
# weighted avg       0.77      0.78      0.77     11826

# %%
max_depth = []
for classifier in forest_base_model:
    max_depth.append(classifier.tree_.max_depth)

# %%
import statistics as stat
stat.median(max_depth)
# Out:
# 40.0

# %% [markdown]
# **INTERPRETATION**
# 1. Completely overfit, just like the Decision Tree basemodel
# 2. Max depth has increased from 30(decisiontree base model) to 40

# %% [markdown]
# ## Random Forest v2

# %% [markdown]
# **REASONING**
# 1. Thus far overfitting has been the largest obstacle for my DecisionTree models and my RandomForest basemodel
# 2. To address this, I am going to set the RandomForest parameters to values that will discourage overfitting (small max_depth, large min_sample_split, etc.)

# %%
forest_v2 = RandomForestClassifier()

weight_dict = {1: 0.5, 2: 3, 3: 10}
weight_dict2 = {1: 0.25, 2: 6, 3: 12}

param_grid= {
    'criterion': ['gini', 'entropy'],
    'class_weight': [weight_dict, weight_dict2],
    'max_depth': [25, 30, 35], 
    'min_samples_split': [10, 15, 20],
    # trying to abide by the MSL should be at least 2xMSS
    'min_samples_leaf': [20, 25, 30],
    ,
    #approx 6 seems to be the optimum number of features to consider
    # https://www.analyticsvidhya.com/blog/2020/03/beginners-guide-random-forest-hyperparameter-tuning/
    
    
}

forest_v2_model = GridSearchCV(estimator = forest_v2, param_grid=param_grid, cv=3)
forest_v2_model.fit(X_train_scaled, y_train)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-155-15e46b411ed9> in <module>
#      19
#      20 forest_v2_model = GridSearchCV(estimator = forest_v2, param_grid=param_grid, cv=3)
# ---> 21 forest_v2_model.fit(X_train_scaled, y_train)
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     734                 return results
#     735
# --> 736             self._run_search(evaluate_candidates)
#     737
#     738         # For multi-metric evaluation, store the best_index_, best_params_ and
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/model_selection/_search.py in _run_search(self, evaluate_candidates)
#    1186     def _run_search(self, evaluate_candidates):
#    1187         """Search all candidates in param_grid"""
# -> 1188         evaluate_candidates(ParameterGrid(self.param_grid))
#    1189
#    1190
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/model_selection/_search.py in evaluate_candidates(candidate_params)
#     706                               n_splits, n_candidates, n_candidates * n_splits))
#     707
# --> 708                 out = parallel(delayed(_fit_and_score)(clone(base_estimator),
#     709                                                        X, y,
#     710                                                        train=train, test=test,
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1049                 self._iterating = self._original_iterator is not None
#    1050
# -> 1051             while self.dispatch_one_batch(iterator):
#    1052                 pass
#    1053
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     864                 return False
#     865             else:
# --> 866                 self._dispatch(tasks)
#     867                 return True
#     868
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/joblib/parallel.py in _dispatch(self, batch)
#     782         with self._lock:
#     783             job_idx = len(self._jobs)
# --> 784             job = self._backend.apply_async(batch, callback=cb)
#     785             # A job can complete so quickly than its callback is
#     786             # called before we get here, causing self._jobs to
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     206     def apply_async(self, func, callback=None):
#     207         """Schedule a func to be run"""
# --> 208         result = ImmediateResult(func)
#     209         if callback:
#     210             callback(result)
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/joblib/_parallel_backends.py in __init__(self, batch)
#     570         # Don't delay the application, to avoid keeping the input
#     571         # arguments in memory
# --> 572         self.results = batch()
#     573
#     574     def get(self):
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/joblib/parallel.py in __call__(self)
#     260         # change the default number of processes to -1
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#     264
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/joblib/parallel.py in <listcomp>(.0)
#     260         # change the default number of processes to -1
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#     264
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/model_selection/_validation.py in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, error_score)
#     529             estimator.fit(X_train, **fit_params)
#     530         else:
# --> 531             estimator.fit(X_train, y_train, **fit_params)
#     532
#     533     except Exception as e:
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/ensemble/_forest.py in fit(self, X, y, sample_weight)
#     384             # parallel_backend contexts set at a higher level,
#     385             # since correctness does not rely on using threads.
# --> 386             trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#     387                              **_joblib_parallel_args(prefer='threads'))(
#     388                 delayed(_parallel_build_trees)(
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1049                 self._iterating = self._original_iterator is not None
#    1050
# -> 1051             while self.dispatch_one_batch(iterator):
#    1052                 pass
#    1053
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     864                 return False
#     865             else:
# --> 866                 self._dispatch(tasks)
#     867                 return True
#     868
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/joblib/parallel.py in _dispatch(self, batch)
#     782         with self._lock:
#     783             job_idx = len(self._jobs)
# --> 784             job = self._backend.apply_async(batch, callback=cb)
#     785             # A job can complete so quickly than its callback is
#     786             # called before we get here, causing self._jobs to
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     206     def apply_async(self, func, callback=None):
#     207         """Schedule a func to be run"""
# --> 208         result = ImmediateResult(func)
#     209         if callback:
#     210             callback(result)
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/joblib/_parallel_backends.py in __init__(self, batch)
#     570         # Don't delay the application, to avoid keeping the input
#     571         # arguments in memory
# --> 572         self.results = batch()
#     573
#     574     def get(self):
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/joblib/parallel.py in __call__(self)
#     260         # change the default number of processes to -1
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#     264
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/joblib/parallel.py in <listcomp>(.0)
#     260         # change the default number of processes to -1
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#     264
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/ensemble/_forest.py in _parallel_build_trees(tree, forest, X, y, sample_weight, tree_idx, n_trees, verbose, class_weight, n_samples_bootstrap)
#     166                                                         indices=indices)
#     167
# --> 168         tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#     169     else:
#     170         tree.fit(X, y, sample_weight=sample_weight, check_input=False)
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     888         """
#     889
# --> 890         super().fit(
#     891             X, y,
#     892             sample_weight=sample_weight,
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     373                                            min_impurity_split)
#     374
# --> 375         builder.build(self.tree_, X, y, sample_weight, X_idx_sorted)
#     376
#     377         if self.n_outputs_ == 1 and is_classifier(self):
#
# KeyboardInterrupt:

# %% [markdown]
# # Merging 2 and 3

# %% [markdown]
# Thus far, performance for many of my models have been decent at predicting if a well is functioning, or not functioning, but has been terrible at correctly predicting if a well is functioning but needs repair
# 1. This can be attributed to the massive class imbalance
#     - A wide variety of different balancing measures (class_weights and SMOTE), and hyperparameter tuning for deciiontrees and randomforests have not been able to achieve a recall of over 50% for functioning-needs repair
# 2. To account for this I will merge 'nonfunctioning' and 'functioning-needs repair'
#     - Classifying funcitioning-needs repair as nonfunctioning is acceptable, as a repair team will be able to either fix a nonfunctioning well, or make repairs to a well that could  become nonfunctioning in the future

# %%
df_binary = df.replace({'status_group': 3}, 2)

# %%
df_binary['status_group'].value_counts()
# Out:
# 1    26127
# 2    21177
# Name: status_group, dtype: int64

# %%
fig, ax = plt.subplots(figsize=(10,5))


imbalance_plot= sns.countplot(ax=ax,
              x='status_group', 
              data=df_binary,
             color = 'orange')

plt.xticks([0,1], 
           ['Functional', 'Non-Functional'],
          fontsize=12)
plt.yticks(fontsize=12)
plt.xlabel(xlabel='Status', fontsize=14)
plt.ylabel(ylabel='Count', fontsize=14);

# %% [markdown]
# This has alleviated the class imbalance tremendously

# %%
#splitting features and target
#creating dummy variables for categorical data
X = df_binary.drop('status_group', axis=1)
X = pd.get_dummies(X, drop_first=True )

y = df_binary['status_group']

#creating training and testing data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size= .25, random_state=42)


#scaling 
scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# ## Decision Tree - Baseline

# %%
dt_base = DecisionTreeClassifier()

dt_base_model = dt_base.fit(X_train_scaled, y_train)

# %%
fig, axes = plt.subplots(nrows = 1,ncols = 1, figsize = (3,3), dpi=300)
tree.plot_tree(dt_base,
               feature_names = X.columns, 
               class_names=np.unique(y).astype('str'),
               filled = True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-163-2766c25d9324> in <module>
#       1 fig, axes = plt.subplots(nrows = 1,ncols = 1, figsize = (3,3), dpi=300)
# ----> 2 tree.plot_tree(dt_base,
#       3                feature_names = X.columns,
#       4                class_names=np.unique(y).astype('str'),
#       5                filled = True)
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/tree/_export.py in plot_tree(decision_tree, max_depth, feature_names, class_names, label, filled, impurity, node_ids, proportion, rotate, rounded, precision, ax, fontsize)
#     191         proportion=proportion, rotate=rotate, rounded=rounded,
#     192         precision=precision, fontsize=fontsize)
# --> 193     return exporter.export(decision_tree, ax=ax)
#     194
#     195
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/tree/_export.py in export(self, decision_tree, ax)
#     607
#     608         for ann in anns:
# --> 609             ann.update_bbox_position_size(renderer)
#     610
#     611         if self.fontsize is None:
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/matplotlib/text.py in update_bbox_position_size(self, renderer)
#     495             posx, posy = trans.transform((posx, posy))
#     496
# --> 497             x_box, y_box, w_box, h_box = _get_textbox(self, renderer)
#     498             self._bbox_patch.set_bounds(0., 0., w_box, h_box)
#     499             self._bbox_patch.set_transform(
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/matplotlib/text.py in _get_textbox(text, renderer)
#      82     tr = Affine2D().rotate(-theta)
#      83
# ---> 84     _, parts, d = text._get_layout(renderer)
#      85
#      86     for t, wh, x, y in parts:
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/matplotlib/text.py in _get_layout(self, renderer)
#     291             clean_line, ismath = self._preprocess_math(line)
#     292             if clean_line:
# --> 293                 w, h, d = renderer.get_text_width_height_descent(
#     294                     clean_line, self._fontproperties, ismath=ismath)
#     295             else:
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py in get_text_width_height_descent(self, s, prop, ismath)
#     235
#     236         flags = get_hinting_flag()
# --> 237         font = self._get_agg_font(prop)
#     238         font.set_text(s, 0.0, flags=flags)
#     239         w, h = font.get_width_height()  # width and height of unrotated string
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py in _get_agg_font(self, prop)
#     270         Get the font for text instance t, caching for efficiency
#     271         """
# --> 272         fname = findfont(prop)
#     273         font = get_font(fname)
#     274
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/matplotlib/font_manager.py in findfont(self, prop, fontext, directory, fallback_to_default, rebuild_if_missing)
#    1312             prop, fontext, directory, fallback_to_default, rebuild_if_missing,
#    1313             rc_params)
# -> 1314         return os.path.realpath(filename)
#    1315
#    1316     @lru_cache()
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/posixpath.py in realpath(filename)
#     389 symbolic links encountered in the path."""
#     390     filename = os.fspath(filename)
# --> 391     path, ok = _joinrealpath(filename[:0], filename, {})
#     392     return abspath(path)
#     393
#
# KeyboardInterrupt:
# Error in callback <function flush_figures at 0x1125150d0> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/ipykernel/pylab/backend_inline.py in flush_figures()
#     119         # ignore the tracking, just draw and close all figures
#     120         try:
# --> 121             return show(True)
#     122         except Exception as e:
#     123             # safely show traceback if in IPython, else raise
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/ipykernel/pylab/backend_inline.py in show(close, block)
#      39     try:
#      40         for figure_manager in Gcf.get_all_fig_managers():
# ---> 41             display(
#      42                 figure_manager.canvas.figure,
#      43                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/IPython/core/display.py in display(include, exclude, metadata, transient, display_id, *objs, **kwargs)
#     311             publish_display_data(data=obj, metadata=metadata, **kwargs)
#     312         else:
# --> 313             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     314             if not format_dict:
#     315                 # nothing to display (e.g. _ipython_display_ took over)
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/IPython/core/formatters.py in format(self, obj, include, exclude)
#     178             md = None
#     179             try:
# --> 180                 data = formatter(obj)
#     181             except:
#     182                 # FIXME: log the exception
#
# <decorator-gen-2> in __call__(self, obj)
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/IPython/core/formatters.py in catch_format_error(method, self, *args, **kwargs)
#     222     """show traceback on failed format call"""
#     223     try:
# --> 224         r = method(self, *args, **kwargs)
#     225     except NotImplementedError:
#     226         # don't warn on NotImplementedErrors
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     246
#     247     if 'png' in formats:
# --> 248         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     249     if 'retina' in formats or 'png2x' in formats:
#     250         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     130         FigureCanvasBase(fig)
#     131
# --> 132     fig.canvas.print_figure(bytes_io, **kw)
#     133     data = bytes_io.getvalue()
#     134     if fmt == 'svg':
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2193                         self.figure.draw(renderer)
#    2194
# -> 2195                     bbox_inches = self.figure.get_tightbbox(
#    2196                         renderer, bbox_extra_artists=bbox_extra_artists)
#    2197                     if pad_inches is None:
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/matplotlib/figure.py in get_tightbbox(self, renderer, bbox_extra_artists)
#    2504
#    2505         for a in artists:
# -> 2506             bbox = a.get_tightbbox(renderer)
#    2507             if bbox is not None and (bbox.width != 0 or bbox.height != 0):
#    2508                 bb.append(bbox)
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/matplotlib/axes/_base.py in get_tightbbox(self, renderer, call_axes_locator, bbox_extra_artists, for_layout_only)
#    4201                     # this artist
#    4202                     continue
# -> 4203             bbox = a.get_tightbbox(renderer)
#    4204             if (bbox is not None
#    4205                     and 0 < bbox.width < np.inf
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/matplotlib/artist.py in get_tightbbox(self, renderer)
#     276             The enclosing bounding box (in figure pixel coordinates).
#     277         """
# --> 278         bbox = self.get_window_extent(renderer)
#     279         if self.get_clip_on():
#     280             clip_box = self.get_clip_box()
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/matplotlib/text.py in get_window_extent(self, renderer)
#    1928
#    1929         if self.arrow_patch is not None:
# -> 1930             bboxes.append(self.arrow_patch.get_window_extent())
#    1931
#    1932         return Bbox.union(bboxes)
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/matplotlib/patches.py in get_window_extent(self, renderer)
#     596
#     597     def get_window_extent(self, renderer=None):
# --> 598         return self.get_path().get_extents(self.get_transform())
#     599
#     600     def _convert_xy_units(self, xy):
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/matplotlib/patches.py in get_path(self)
#    4126         in display coordinates.
#    4127         """
# -> 4128         _path, fillable = self.get_path_in_displaycoord()
#    4129         if np.iterable(fillable):
#    4130             _path = Path.make_compound_path(*_path)
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/matplotlib/patches.py in get_path_in_displaycoord(self)
#    4139             posB = self._convert_xy_units(self._posA_posB[1])
#    4140             (posA, posB) = self.get_transform().transform((posA, posB))
# -> 4141             _path = self.get_connectionstyle()(posA, posB,
#    4142                                                patchA=self.patchA,
#    4143                                                patchB=self.patchB,
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/matplotlib/patches.py in __call__(self, posA, posB, shrinkA, shrinkB, patchA, patchB)
#    2491             path = self.connect(posA, posB)
#    2492             clipped_path = self._clip(path, patchA, patchB)
# -> 2493             shrunk_path = self._shrink(clipped_path, shrinkA, shrinkB)
#    2494             return shrunk_path
#    2495
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/matplotlib/patches.py in _shrink(self, path, shrinkA, shrinkB)
#    2472                 insideA = inside_circle(*path.vertices[0], shrinkA)
#    2473                 try:
# -> 2474                     left, path = split_path_inout(path, insideA)
#    2475                 except ValueError:
#    2476                     pass
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/matplotlib/bezier.py in split_path_inout(path, inside, tolerance, reorder_inout)
#     367
#     368     bp = bezier_path.reshape((-1, 2))
# --> 369     left, right = split_bezier_intersecting_with_closedpath(
#     370         bp, inside, tolerance)
#     371     if len(left) == 2:
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/matplotlib/bezier.py in split_bezier_intersecting_with_closedpath(bezier, inside_closedpath, tolerance)
#     330     bezier_point_at_t = bz.point_at_t
#     331
# --> 332     t0, t1 = find_bezier_t_intersecting_with_closedpath(
#     333         bezier_point_at_t, inside_closedpath, tolerance=tolerance)
#     334
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/matplotlib/bezier.py in find_bezier_t_intersecting_with_closedpath(bezier_point_at_t, inside_closedpath, t0, t1, tolerance)
#     167         # calculate the middle point
#     168         middle_t = 0.5 * (t0 + t1)
# --> 169         middle = bezier_point_at_t(middle_t)
#     170         middle_inside = inside_closedpath(middle)
#     171
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/matplotlib/bezier.py in point_at_t(self, t)
#     219     def point_at_t(self, t):
#     220         """Evaluate curve at a single point *t*. Returns a Tuple[float*d]."""
# --> 221         return tuple(self(t))
#     222
#     223     @property
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/matplotlib/bezier.py in __call__(self, t)
#     214         """
#     215         t = np.asarray(t)
# --> 216         return (np.power.outer(1 - t, self._orders[::-1])
#     217                 * np.power.outer(t, self._orders)) @ self._px
#     218
#
# KeyboardInterrupt:

# %%
print(classification_report(y_train, dt_base.predict(X_train_scaled)))
# Out:
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00     19593
#            2       1.00      1.00      1.00     15885
#
#     accuracy                           1.00     35478
#    macro avg       1.00      1.00      1.00     35478
# weighted avg       1.00      1.00      1.00     35478

# %%
dt_base.tree_.max_depth
# Out:
# 40

# %%
print(classification_report(y_test, dt_base.predict(X_test_scaled)))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.80      0.81      0.81      6534
#            2       0.76      0.76      0.76      5292
#
#     accuracy                           0.79     11826
#    macro avg       0.78      0.78      0.78     11826
# weighted avg       0.79      0.79      0.79     11826

# %%
plot_confusion_matrix(dt_base, X_test_scaled, y_test,
                     cmap=plt.cm.Blues)
plt.show()

# %% [markdown]
# **INTERPRETATION**
# 1. Training is completely overfit (to be exptected)
# 2. FP and FN are nearly identical... does this mean the model is guessing 50/50?

# %% [markdown]
# ## Decision Tree v2 (Gridsearch)

# %%
dt_v2 = DecisionTreeClassifier()

param_grid = {
    'criterion': ['gini', 'entropy'],
    'class_weight': ['balanced', None],
    'max_depth' : [10, 20, 30],
    'min_samples_split': [5, 10, 15],
    'min_samples_leaf': [10, 20, 30],
}

dt_v2_model = GridSearchCV(estimator = dt_v2, param_grid=param_grid, cv=3)
dt_v2_model.fit(X_train_scaled, y_train)
# Out:
# GridSearchCV(cv=3, estimator=DecisionTreeClassifier(),
#              param_grid={'class_weight': ['balanced', None],
#                          'criterion': ['gini', 'entropy'],
#                          'max_depth': [10, 20, 30],
#                          'min_samples_leaf': [10, 20, 30],
#                          'min_samples_split': [5, 10, 15]})

# %%
print(dt_v2_model.best_params_)
# Out:
# {'class_weight': None, 'criterion': 'gini', 'max_depth': 20, 'min_samples_leaf': 10, 'min_samples_split': 10}

# %%
print(classification_report(y_train, dt_v2_model.predict(X_train_scaled)))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.85      0.91      0.88     19593
#            2       0.88      0.80      0.84     15885
#
#     accuracy                           0.86     35478
#    macro avg       0.86      0.86      0.86     35478
# weighted avg       0.86      0.86      0.86     35478

# %%
print(classification_report(y_test, dt_v2_model.predict(X_test_scaled)))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.79      0.85      0.82      6534
#            2       0.79      0.72      0.76      5292
#
#     accuracy                           0.79     11826
#    macro avg       0.79      0.79      0.79     11826
# weighted avg       0.79      0.79      0.79     11826

# %%
plot_confusion_matrix(dt_v2_model, X_test_scaled, y_test,
                     cmap=plt.cm.Blues)
plt.show()

# %% [markdown]
# **INTERPRETATION**
# 1. Accuracy remains the same as basemodel
# 2. recall for Functioning improved
# 3. recall for Nonfunctioning has dropped by 4%
# 4. False Negatives are higher - worst case

# %% [markdown]
# ## Decision Tree v3 - LAST TREE

# %% [markdown]
# **INTENTIONS**
# 1. I will be weighting 'nonfunctioning' slightly more and 'functioning' slightly less to see if FN will drop

# %%
dt_v3 = DecisionTreeClassifier(criterion='gini', max_depth=20, min_samples_split=10)

weight_dict = {1: 0.75, 2: 1.25}
weight_dict2= {1: 0.9, 2: 1.1}

param_grid = {
    'class_weight': [weight_dict, weight_dict2],
    'min_samples_leaf': [5, 7, 10],
}

dt_v3_model = GridSearchCV(estimator = dt_v3, param_grid=param_grid, cv=3)
dt_v3_model.fit(X_train_scaled, y_train)
# Out:
# GridSearchCV(cv=3,
#              estimator=DecisionTreeClassifier(max_depth=20,
#                                               min_samples_split=10),
#              param_grid={'class_weight': [{1: 0.75, 2: 1.25}, {1: 0.9, 2: 1.1}],
#                          'min_samples_leaf': [5, 7, 10]})

# %%
print(dt_v3_model.best_params_)
print('-------------------------------------------------------------------')
print(classification_report(y_train, dt_v3_model.predict(X_train_scaled)))
print('-------------------------------------------------------------------')
print(classification_report(y_test, dt_v3_model.predict(X_test_scaled)))

plot_confusion_matrix(dt_v3_model, X_test_scaled, y_test,
                     cmap=plt.cm.Blues)
plt.show()
# Out:
# {'class_weight': {1: 0.9, 2: 1.1}, 'min_samples_leaf': 5}
# -------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            1       0.89      0.91      0.90     19593
#            2       0.88      0.86      0.87     15885
#
#     accuracy                           0.89     35478
#    macro avg       0.89      0.89      0.89     35478
# weighted avg       0.89      0.89      0.89     35478
#
# -------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            1       0.80      0.82      0.81      6534
#            2       0.77      0.75      0.76      5292
#
#     accuracy                           0.79     11826
#    macro avg       0.79      0.78      0.78     11826
# weighted avg       0.79      0.79      0.79     11826

# %% [markdown]
# **INTERPRETATION**
# 1. Adjusting class weights slightly in favor of nonfunctional had a very minimal decrease in FN
# 2. Recall for nonfunctinoal has increased by 3%, sacrificing 3% recall for functional

# %% [markdown]
# ### Best Decision Tree = dt_v3_model
# - Accuracy : 79%
# - Nonfunctional Recall : 75%
# - Nonfunctional F1: 76%

# %% [markdown]
# # Random Forest - Baseline

# %% [markdown]
# 1. I am expecting RandomForest models to have an improvement in performance due to ###########
# 2. Viewing feature importance will be a helpful insight

# %%
forest_base = RandomForestClassifier()
forest_base_model = forest_base.fit(X_train_scaled, y_train)

# %%
print(classification_report(y_train, forest_base_model.predict(X_train_scaled)))
print('-------------------------------------------------------------------')
print(classification_report(y_test, forest_base_model.predict(X_test_scaled)))

plot_confusion_matrix(forest_base_model, X_test_scaled, y_test,
                     cmap=plt.cm.Blues)
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00     19593
#            2       1.00      1.00      1.00     15885
#
#     accuracy                           1.00     35478
#    macro avg       1.00      1.00      1.00     35478
# weighted avg       1.00      1.00      1.00     35478
#
# -------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            1       0.82      0.86      0.84      6534
#            2       0.82      0.77      0.79      5292
#
#     accuracy                           0.82     11826
#    macro avg       0.82      0.82      0.82     11826
# weighted avg       0.82      0.82      0.82     11826

# %%
max_depth_base = []
for classifier in forest_base_model:
    max_depth_base.append(classifier.tree_.max_depth)

stat.median(max_depth_base)
# Out:
# 41.0

# %%
def plot_feature_importances_base(model):
    n_features = X_train.shape[1]
    plt.figure(figsize=(20,20))
    plt.barh(range(n_features), model.feature_importances_, align='center') 
    plt.yticks(np.arange(n_features), X_train.columns.values) 
    plt.xlabel('Feature importance')
    plt.ylabel('Feature')

# %%
plot_feature_importances_base(forest_base_model)

# %% [markdown]
# **INTERPRETATION**
# 1. Performance is nearly identical to the DecisionTree basemodel
#     - Completely overfit
#     - this gives me little faith that RandomForest will help provide optimal results

# %% [markdown]
# ## RandomForest v2 (Gridsearch)

# %%
forest_v2 = RandomForestClassifier()

param_grid= {
    'criterion': ['gini', 'entropy'],
    'class_weight': ['balanced', None],
    'max_depth': [25, 30, 35], 
    'min_samples_split': [10, 15, 20],
    'min_samples_leaf': [20, 25, 30],    
}

forest_v2_model = GridSearchCV(estimator = forest_v2, param_grid=param_grid, cv=3)
forest_v2_model.fit(X_train_scaled, y_train)
# Out:
# GridSearchCV(cv=3, estimator=RandomForestClassifier(),
#              param_grid={'class_weight': ['balanced', None],
#                          'criterion': ['gini', 'entropy'],
#                          'max_depth': [25, 30, 35],
#                          'min_samples_leaf': [20, 25, 30],
#                          'min_samples_split': [10, 15, 20]})

# %%
print(forest_v2_model.best_params_)
print('-------------------------------------------------------------------')
print(classification_report(y_train, forest_v2_model.predict(X_train_scaled)))
print('-------------------------------------------------------------------')
print(classification_report(y_test, forest_v2_model.predict(X_test_scaled)))

plot_confusion_matrix(forest_v2_model, X_test_scaled, y_test,
                     cmap=plt.cm.Blues)
plt.show()
# Out:
# {'class_weight': None, 'criterion': 'entropy', 'max_depth': 35, 'min_samples_leaf': 20, 'min_samples_split': 15}
# -------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            1       0.80      0.90      0.84     19593
#            2       0.85      0.72      0.78     15885
#
#     accuracy                           0.82     35478
#    macro avg       0.82      0.81      0.81     35478
# weighted avg       0.82      0.82      0.81     35478
#
# -------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            1       0.77      0.87      0.82      6534
#            2       0.81      0.68      0.74      5292
#
#     accuracy                           0.79     11826
#    macro avg       0.79      0.78      0.78     11826
# weighted avg       0.79      0.79      0.79     11826

# %% [markdown]
# **INTERPRETATION**
# 1. Surprisingly, this model does not produce much better results than the best decisiontree model
#     - 79% accuracy for both
# 2. Most importantly, FN are much worse
#     - nonfunctional recall has dropped 8%

# %%
def plot_feature_importances(model):
    n_features = X_train.shape[1]
    plt.figure(figsize=(20,20))
    plt.barh(range(n_features), model.best_estimator_.feature_importances_, align='center') 
    plt.yticks(np.arange(n_features), X_train.columns.values) 
    plt.xlabel('Feature importance')
    plt.ylabel('Feature')

# %%
plot_feature_importances(forest_v2_model)

# %% [markdown]
# ## Random Forest v3

# %% [markdown]
# **INTENTIONS**
# 1. All models have been favoring class_weight = None, so I am going to force weighted scale in favor of nonfunctional to see if FN go down

# %%
forest_v3 = RandomForestClassifier(criterion='entropy', 
                                   max_depth=35, 
                                   class_weight={1: 0.75, 2:1.25}, 
                                   min_samples_split=15,  )

param_grid= {
    'min_samples_leaf': [10, 15, 20],    
}

forest_v3_model = GridSearchCV(estimator = forest_v3, param_grid=param_grid, cv=3)
forest_v3_model.fit(X_train_scaled, y_train)
# Out:
# GridSearchCV(cv=3,
#              estimator=RandomForestClassifier(class_weight={1: 0.75, 2: 1.25},
#                                               criterion='entropy', max_depth=35,
#                                               min_samples_split=15),
#              param_grid={'min_samples_leaf': [10, 15, 20]})

# %%
print(forest_v3_model.best_params_)
print('-------------------------------------------------------------------')
print(classification_report(y_train, forest_v3_model.predict(X_train_scaled)))
print('-------------------------------------------------------------------')
print(classification_report(y_test, forest_v3_model.predict(X_test_scaled)))

plot_confusion_matrix(forest_v3_model, X_test_scaled, y_test,
                     cmap=plt.cm.Blues)
plt.show()
# Out:
# {'min_samples_leaf': 10}
# -------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            1       0.88      0.79      0.83     19593
#            2       0.77      0.87      0.82     15885
#
#     accuracy                           0.83     35478
#    macro avg       0.83      0.83      0.82     35478
# weighted avg       0.83      0.83      0.83     35478
#
# -------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            1       0.85      0.75      0.80      6534
#            2       0.73      0.83      0.78      5292
#
#     accuracy                           0.79     11826
#    macro avg       0.79      0.79      0.79     11826
# weighted avg       0.80      0.79      0.79     11826

# %% [markdown]
# **INTERPRETATION**
# 1. Forcing the class weight significantly reduced FN
#     - the count of FN and FP have essentially switched from the previous model , which is a small step in the right dirrection
#     - curious to see how a Decisiontree would handle weight coercion

# %%
plot_feature_importances(forest_v3_model)

# %% [markdown]
# # RandomForest v4

# %% [markdown]
# **INTENTIONS**
# 1. Keeping the forced weight, I want to find the optimal parameters surrounding it

# %%
forest_v4 = RandomForestClassifier(max_depth=35, class_weight={1: 0.75, 2:1.25})

param_grid= {
    'criterion': ['gini', 'entropy'],
    'min_samples_split': [10, 15, 20],
    'min_samples_leaf': [20, 25, 30],    
}

forest_v4_model = GridSearchCV(estimator = forest_v4, param_grid=param_grid, cv=3)
forest_v4_model.fit(X_train_scaled, y_train)
# Out:
# GridSearchCV(cv=3,
#              estimator=RandomForestClassifier(class_weight={1: 0.75, 2: 1.25},
#                                               max_depth=35),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'min_samples_leaf': [20, 25, 30],
#                          'min_samples_split': [10, 15, 20]})

# %%
print(forest_v4_model.best_params_)
print('-------------------------------------------------------------------')
print(classification_report(y_train, forest_v4_model.predict(X_train_scaled)))
print('-------------------------------------------------------------------')
print(classification_report(y_test, forest_v4_model.predict(X_test_scaled)))

plot_confusion_matrix(forest_v4_model, X_test_scaled, y_test,
                     cmap=plt.cm.Blues)
plt.show()
# Out:
# {'criterion': 'entropy', 'min_samples_leaf': 20, 'min_samples_split': 10}
# -------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            1       0.87      0.74      0.80     19593
#            2       0.73      0.86      0.79     15885
#
#     accuracy                           0.80     35478
#    macro avg       0.80      0.80      0.80     35478
# weighted avg       0.81      0.80      0.80     35478
#
# -------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            1       0.85      0.71      0.77      6534
#            2       0.70      0.84      0.76      5292
#
#     accuracy                           0.77     11826
#    macro avg       0.77      0.78      0.77     11826
# weighted avg       0.78      0.77      0.77     11826

# %% [markdown]
# **INTERPRETATION**
# 1. Recall has increased 1% as FN have dropped slightly from the previous model
# 2. FP continue to rise at a larger rate than FN are falling
# 3. I consider the performance of this model slightly worse than the previous

# %%
plot_feature_importances(forest_v4_model)

# %% [markdown]
# # SVM - Baseline

# %%
svm_base = SVC()
svm_base_model = svm_base.fit(X_train_scaled, y_train)

# %%
print(classification_report(y_train, svm_base_model.predict(X_train_scaled)))
print('-------------------------------------------------------------------')
print(classification_report(y_test, svm_base_model.predict(X_test_scaled)))

plot_confusion_matrix(svm_base_model, X_test_scaled, y_test,
                     cmap=plt.cm.Blues)
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#            1       0.79      0.91      0.84     19593
#            2       0.86      0.69      0.77     15885
#
#     accuracy                           0.81     35478
#    macro avg       0.83      0.80      0.81     35478
# weighted avg       0.82      0.81      0.81     35478
#
# -------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            1       0.76      0.89      0.82      6534
#            2       0.83      0.66      0.73      5292
#
#     accuracy                           0.79     11826
#    macro avg       0.80      0.77      0.78     11826
# weighted avg       0.79      0.79      0.78     11826

# %% [markdown]
# **INTERPRETATION**
# 1. This is the first base model that has not completely overfit the training data
#     - This makes sense considering SVM naturally tries to generalize classification
# 2. I have faith that an optimized SVM use a soft margin that will produce good results, given the fact that I am okay with accepting higher rates of FP

# %% [markdown]
# ## SVM RBF

# %%
svm_rbf = SVC()

param_grid= {
    'C': [0.1, 1, 10],
    'gamma': [0.1, 1, 50]   
}

svm_rbf_model = GridSearchCV(estimator = svm_rbf, param_grid=param_grid, cv=3)
svm_rbf_model.fit(X_train_scaled, y_train)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-255-bfe61654a025> in <module>
#       7
#       8 svm_rbf_model = GridSearchCV(estimator = svm_rbf, param_grid=param_grid, cv=3)
# ----> 9 svm_rbf_model.fit(X_train_scaled, y_train)
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     734                 return results
#     735
# --> 736             self._run_search(evaluate_candidates)
#     737
#     738         # For multi-metric evaluation, store the best_index_, best_params_ and
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/model_selection/_search.py in _run_search(self, evaluate_candidates)
#    1186     def _run_search(self, evaluate_candidates):
#    1187         """Search all candidates in param_grid"""
# -> 1188         evaluate_candidates(ParameterGrid(self.param_grid))
#    1189
#    1190
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/model_selection/_search.py in evaluate_candidates(candidate_params)
#     706                               n_splits, n_candidates, n_candidates * n_splits))
#     707
# --> 708                 out = parallel(delayed(_fit_and_score)(clone(base_estimator),
#     709                                                        X, y,
#     710                                                        train=train, test=test,
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1049                 self._iterating = self._original_iterator is not None
#    1050
# -> 1051             while self.dispatch_one_batch(iterator):
#    1052                 pass
#    1053
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     864                 return False
#     865             else:
# --> 866                 self._dispatch(tasks)
#     867                 return True
#     868
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/joblib/parallel.py in _dispatch(self, batch)
#     782         with self._lock:
#     783             job_idx = len(self._jobs)
# --> 784             job = self._backend.apply_async(batch, callback=cb)
#     785             # A job can complete so quickly than its callback is
#     786             # called before we get here, causing self._jobs to
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     206     def apply_async(self, func, callback=None):
#     207         """Schedule a func to be run"""
# --> 208         result = ImmediateResult(func)
#     209         if callback:
#     210             callback(result)
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/joblib/_parallel_backends.py in __init__(self, batch)
#     570         # Don't delay the application, to avoid keeping the input
#     571         # arguments in memory
# --> 572         self.results = batch()
#     573
#     574     def get(self):
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/joblib/parallel.py in __call__(self)
#     260         # change the default number of processes to -1
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#     264
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/joblib/parallel.py in <listcomp>(.0)
#     260         # change the default number of processes to -1
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#     264
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/model_selection/_validation.py in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, error_score)
#     529             estimator.fit(X_train, **fit_params)
#     530         else:
# --> 531             estimator.fit(X_train, y_train, **fit_params)
#     532
#     533     except Exception as e:
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/svm/_base.py in fit(self, X, y, sample_weight)
#     215
#     216         seed = rnd.randint(np.iinfo('i').max)
# --> 217         fit(X, y, sample_weight, solver_type, kernel, random_seed=seed)
#     218         # see comment on the other call to np.iinfo in this file
#     219
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/svm/_base.py in _dense_fit(self, X, y, sample_weight, solver_type, kernel, random_seed)
#     266         self.support_, self.support_vectors_, self._n_support, \
#     267             self.dual_coef_, self.intercept_, self._probA, \
# --> 268             self._probB, self.fit_status_ = libsvm.fit(
#     269                 X, y,
#     270                 svm_type=solver_type, sample_weight=sample_weight,
#
# KeyboardInterrupt:

# %% [markdown]
# No results after 2.5 hours

# %% [markdown]
# # XGBoost - Baseline

# %%
from xgboost import XGBClassifier

# %%
xgb_base = XGBClassifier()
xgb_base_model = xgb_base.fit(X_train_scaled, y_train)

# %%
print(classification_report(y_train, xgb_base_model.predict(X_train_scaled)))
print('-------------------------------------------------------------------')
print(classification_report(y_test, xgb_base_model.predict(X_test_scaled)))

plot_confusion_matrix(xgb_base_model, X_test_scaled, y_test,
                     cmap=plt.cm.Blues)
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#            1       0.85      0.93      0.88     19593
#            2       0.90      0.79      0.84     15885
#
#     accuracy                           0.87     35478
#    macro avg       0.87      0.86      0.86     35478
# weighted avg       0.87      0.87      0.87     35478
#
# -------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            1       0.80      0.88      0.84      6534
#            2       0.83      0.72      0.77      5292
#
#     accuracy                           0.81     11826
#    macro avg       0.81      0.80      0.80     11826
# weighted avg       0.81      0.81      0.81     11826

# %% [markdown]
# **INTERPRETATION**
# 1. The basemodel has achieved much better results than many of my attempts to omptimize DT and RF
# 2. Perhaps adjusting weights will once again force the algorithm to predict less FN

# %% [markdown]
# ## XGBoost v2

# %%
xgb_v2 = XGBClassifier()

param_grid = {
    'learning_rate' : [0.1, 0.2],
    'max_depth': [4, 6, 8],
    'min_child_weight': [1, 2],
    'sub_sample': [0.5, 0.7],
    
}

xgb_v2_model = GridSearchCV(estimator = xgb_v2, param_grid=param_grid, cv=3)
xgb_v2_model.fit(X_train_scaled, y_train)
# Out:
# [15:36:49] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [15:36:57] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [15:37:04] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [15:37:09] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [15:37:15] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [15:37:20] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [15:37:26] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [15:37:34] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [15:37:40] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [15:37:46] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [15:37:51] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [15:37:56] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [15:38:01] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [15:38:09] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [15:38:16] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [15:38:24] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [15:38:31] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [15:38:38] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [15:38:45] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [15:38:52] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [15:38:59] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [15:39:06] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
# [15:39:13] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [15:39:20] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [15:39:27] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [15:39:37] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [15:39:46] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [15:39:55] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [15:40:04] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [15:40:14] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [15:40:23] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [15:40:32] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [15:40:42] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [15:40:51] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [15:41:01] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [15:41:10] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [15:41:19] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [15:41:25] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [15:41:32] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [15:41:37] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [15:41:42] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [15:41:47] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [15:41:52] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [15:41:57] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
# [15:42:02] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [15:42:06] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [15:42:11] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [15:42:16] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [15:42:21] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [15:42:28] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [15:42:35] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [15:42:42] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [15:42:49] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [15:42:56] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [15:43:03] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [15:43:10] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [15:43:17] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [15:43:24] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [15:43:31] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [15:43:38] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [15:43:45] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [15:43:54] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [15:44:03] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [15:44:13] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [15:44:22] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [15:44:35] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
# [15:44:50] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [15:45:13] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [15:45:30] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [15:45:48] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [15:46:01] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [15:46:16] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [15:46:26] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
# GridSearchCV(cv=3,
#              estimator=XGBClassifier(base_score=None, booster=None,
#                                      colsample_bylevel=None,
#                                      colsample_bynode=None,
#                                      colsample_bytree=None, gamma=None,
#                                      gpu_id=None, importance_type='gain',
#                                      interaction_constraints=None,
#                                      learning_rate=None, max_delta_step=None,
#                                      max_depth=None, min_child_weight=None,
#                                      missing=nan, monotone_constraints=None,
#                                      n_estimators=100, n_jobs=None,
#                                      num_parallel_tree=None, random_state=None,
#                                      reg_alpha=None, reg_lambda=None,
#                                      scale_pos_weight=None, subsample=None,
#                                      tree_method=None, validate_parameters=None,
#                                      verbosity=None),
#              param_grid={'learning_rate': [0.1, 0.2], 'max_depth': [4, 6, 8],
#                          'min_child_weight': [1, 2], 'sub_sample': [0.5, 0.7]})

# %%
print(xgb_v2_model.best_params_)
print('-------------------------------------------------------------------')
print(classification_report(y_train, xgb_v2_model.predict(X_train_scaled)))
print('-------------------------------------------------------------------')
print(classification_report(y_test, xgb_v2_model.predict(X_test_scaled)))

plot_confusion_matrix(xgb_v2_model, X_test_scaled, y_test,
                     cmap=plt.cm.Blues)
plt.show()
# Out:
# {'learning_rate': 0.2, 'max_depth': 8, 'min_child_weight': 1, 'sub_sample': 0.5}
# -------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            1       0.87      0.94      0.90     19593
#            2       0.92      0.82      0.87     15885
#
#     accuracy                           0.89     35478
#    macro avg       0.89      0.88      0.89     35478
# weighted avg       0.89      0.89      0.89     35478
#
# -------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            1       0.80      0.88      0.84      6534
#            2       0.83      0.73      0.78      5292
#
#     accuracy                           0.81     11826
#    macro avg       0.82      0.80      0.81     11826
# weighted avg       0.81      0.81      0.81     11826

# %% [markdown]
# **INTERPRETATION**
# 1. Barely any difference
# 2. While these results are 'good', they are not optimized for my business problem
#     - going to use scale_pos_weight to attempt this

# %%
xgb_v3 = XGBClassifier(sub_sample=0.5, scale_pos_weight=2, random_state=42)


param_grid = {
    'max_depth': [8, 10, 12],
    'learning_rate': [0.1, 0.075, 0.05]
}

xgb_v3_model = GridSearchCV(estimator = xgb_v3, param_grid=param_grid, cv=3)
xgb_v3_model.fit(X_train_scaled, y_train)
# Out:
# [16:09:43] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:09:54] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:10:05] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:10:19] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:10:31] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:10:44] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:10:56] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:11:10] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:11:24] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:11:39] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:11:48] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:11:57] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:12:07] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:12:18] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:12:30] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:12:42] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:12:56] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:13:10] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:13:25] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:13:34] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:13:44] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:13:53] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
# [16:14:05] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:14:17] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:14:28] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:14:43] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:14:59] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:15:16] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
# GridSearchCV(cv=3,
#              estimator=XGBClassifier(base_score=None, booster=None,
#                                      colsample_bylevel=None,
#                                      colsample_bynode=None,
#                                      colsample_bytree=None, gamma=None,
#                                      gpu_id=None, importance_type='gain',
#                                      interaction_constraints=None,
#                                      learning_rate=None, max_delta_step=None,
#                                      max_depth=None, min_child_weight=None,
#                                      missing=nan, monotone_constraints=None,
#                                      n_estimators=100, n_jobs=None,
#                                      num_parallel_tree=None, random_state=42,
#                                      reg_alpha=None, reg_lambda=None,
#                                      scale_pos_weight=2, sub_sample=0.5,
#                                      subsample=None, tree_method=None,
#                                      validate_parameters=None, verbosity=None),
#              param_grid={'learning_rate': [0.1, 0.075, 0.05],
#                          'max_depth': [8, 10, 12]})

# %%
print(xgb_v3_model.best_params_)
print('-------------------------------------------------------------------')
print(classification_report(y_train, xgb_v3_model.predict(X_train_scaled)))
print('-------------------------------------------------------------------')
print(classification_report(y_test, xgb_v3_model.predict(X_test_scaled)))

plot_confusion_matrix(xgb_v3_model, X_test_scaled, y_test,
                     cmap=plt.cm.Blues)
plt.show()
# Out:
# {'learning_rate': 0.1, 'max_depth': 12}
# -------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            1       0.96      0.89      0.92     19593
#            2       0.87      0.95      0.91     15885
#
#     accuracy                           0.92     35478
#    macro avg       0.92      0.92      0.92     35478
# weighted avg       0.92      0.92      0.92     35478
#
# -------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            1       0.85      0.78      0.81      6534
#            2       0.75      0.83      0.79      5292
#
#     accuracy                           0.80     11826
#    macro avg       0.80      0.81      0.80     11826
# weighted avg       0.81      0.80      0.80     11826

# %% [markdown]
# **INTERPRETATION**
# 1. Adjusting scale_pos_weight has made the model less likely to predict FN
# 2. There still seems to be some overfitting

# %%
xgb_v4 = XGBClassifier(sub_sample=0.5, scale_pos_weight=2, learning_rate=0.2, random_state=42)


param_grid = {
    'sub_sample' : [0.5, 0.4],
    'max_depth': [6, 7, 8]
    
}

xgb_v4_model = GridSearchCV(estimator = xgb_v4, param_grid=param_grid, cv=3)
xgb_v4_model.fit(X_train_scaled, y_train)
# Out:
# [13:54:08] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:54:18] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:54:26] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:54:34] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:54:41] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:54:49] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:54:56] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:55:04] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:55:12] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:55:20] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:55:29] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:55:37] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:55:45] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:55:55] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:56:04] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:56:13] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:56:23] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:56:33] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:56:42] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
# GridSearchCV(cv=3,
#              estimator=XGBClassifier(base_score=None, booster=None,
#                                      colsample_bylevel=None,
#                                      colsample_bynode=None,
#                                      colsample_bytree=None, gamma=None,
#                                      gpu_id=None, importance_type='gain',
#                                      interaction_constraints=None,
#                                      learning_rate=0.2, max_delta_step=None,
#                                      max_depth=None, min_child_weight=None,
#                                      missing=nan, monotone_constraints=None,
#                                      n_estimators=100, n_jobs=None,
#                                      num_parallel_tree=None, random_state=42,
#                                      reg_alpha=None, reg_lambda=None,
#                                      scale_pos_weight=2, sub_sample=0.5,
#                                      subsample=None, tree_method=None,
#                                      validate_parameters=None, verbosity=None),
#              param_grid={'max_depth': [6, 7, 8], 'sub_sample': [0.5, 0.4]})

# %%
print(xgb_v4_model.best_params_)
print('-------------------------------------------------------------------')
print(classification_report(y_train, xgb_v4_model.predict(X_train_scaled)))
print('-------------------------------------------------------------------')
print(classification_report(y_test, xgb_v4_model.predict(X_test_scaled)))
# Out:
# {'max_depth': 8, 'sub_sample': 0.5}
# -------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            1       0.94      0.85      0.89     19593
#            2       0.83      0.93      0.88     15885
#
#     accuracy                           0.88     35478
#    macro avg       0.88      0.89      0.88     35478
# weighted avg       0.89      0.88      0.88     35478
#
# -------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            1       0.85      0.76      0.81      6534
#            2       0.74      0.84      0.79      5292
#
#     accuracy                           0.80     11826
#    macro avg       0.80      0.80      0.80     11826
# weighted avg       0.80      0.80      0.80     11826

# %%
fig, ax = plt.subplots(figsize=(7,7))

plot_confusion_matrix(xgb_v4_model, 
                      X_test_scaled, 
                      y_test,
                      normalize='true',
                      ax=ax,
                     cmap=plt.cm.Blues)
plt.xticks([0,1], ['F', 'NF'])
plt.yticks([0,1], ['F', 'NF'], )
plt.show()

# %%
plot_feature_importances(xgb_v4_model)

# %% [markdown]
# **INTERPRETATION**
# 1. There may be only slightly less overfitting as the test accuracy remains the same, but the train accuracy has fallen by 5%
# 2. FN slightly lower than previous model
# 3. Compared to the best RandomForest model, recall, f1-score, and accuracy have all improved by 1%
